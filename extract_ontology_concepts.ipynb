# %%
# !curl -H "Authorization: apikey token=87918894-263d-4f71-9b22-bfc345c1800d" "https://data.bioontology.org/ontologies/CHEBI/classes?page=1"
# Out:
# {"page":1,"pageCount":4417,"totalCount":220816,"prevPage":null,"nextPage":2,"links":{"nextPage":"https://data.bioontology.org/ontologies/CHEBI/classes?page=2","prevPage":null},"collection":[{"prefLabel":"CHEBI_23680","synonym":[],"definition":[],"cui":[],"semanticType":[],"obsolete":true,"@id":"http://purl.obolibrary.org/obo/CHEBI_23680","@type":"http://www.w3.org/2002/07/owl#Class","links":{"self":"https://data.bioontology.org/ontologies/CHEBI/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FCHEBI_23680","ontology":"https://data.bioontology.org/ontologies/CHEBI","children":"https://data.bioontology.org/ontologies/CHEBI/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FCHEBI_23680/children","parents":"https://data.bioontology.org/ontologies/CHEBI/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FCHEBI_23680/parents","descendants":"https://data.bioontology.org/ontologies/CHEBI/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FCHEBI_23680/descendants","ancestors":"https://data.bioontology.org/ontologies/CHEBI/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FCHEBI_23680/ancestors","instances":"https://data.bioontology.org/ontologies/CHEBI/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FCHEBI_23680/instances","tree":"https://data.bioontology.org/ontologies/CHEBI/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FCHEBI_23680/tree","notes":"https://data.bioontology.org/ontologies/CHEBI/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FCHEBI_23680/notes","mappings":"https://data.bioontology.org/ontologies/CHEBI/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FCHEBI_23680/mappings","ui":"http://bioportal.bioontology.org/ontologies/CHEBI?p=classes&conceptid=http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FCHEBI_23680","@context":{"self":"http://www.w3.org/2002/07/owl#Class","ontology":"http://data.bioontology.org/metadata/Ontology","children":"http://www.w3.org/2002/07/owl#Class","parents":"http://www.w3.org/2002/07/owl#Class","descendants":"http://www.w3.org/2002/07/owl#Class","ancestors":"http://www.w3.org/2002/07/owl#Class","instances":"http://data.bioontology.org/metadata/Instance","tree":"http://www.w3.org/2002/07/owl#Class","notes":"http://data.bioontology.org/metadata/Note","mappings":"http://data.bioontology.org/metadata/Mapping","ui":"http://www.w3.org/2002/07/owl#Class"}},"@context":{"@vocab":"http://data.bioontology.org/metadata/","prefLabel":"http://www.w3.org/2004/02/skos/core#prefLabel","synonym":"http://www.w3.org/2004/02/skos/core#altLabel","definition":"http://www.w3.org/2004/02/skos/core#definition","obsolete":"http://www.w3.org/2002/07/owl#deprecated","semanticType":"http://bioportal.bioontology.org/ontologies/umls/hasSTY","cui":"http://bioportal.bioontology.org/ontologies/umls/cui","@language":"en"}},{"prefLabel":"3beta,23-dihydroxyurs-12-en-28-oic acid 28-O-beta-D-glucopyranoside","synonym":["1-O-[3beta,23-dihydroxy-28-oxours-12-en-28-yl]-beta-D-glucopyranose"],"definition":["A triterpenoid saponin that is 28-O-beta-D-glucopyranosyl derivative of 23-hydroxyursolic acid. It has been isolated from the leaves and twigs of Juglans sinensis."],"cui":[],"semanticType":[],"obsolete":false,"@id":"http://purl.obolibrary.org/obo/CHEBI_67943","@type":"http://www.w3.org/2002/07/owl#Class","links":{"self":"https://data.bioontology.org/ontologies/CHEBI/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FCHEBI_67943","ontology":"https://data.bioontology.org/ontologies/CHEBI","children":"https://data.bioontology.org/ontologies/CHEBI/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FCHEBI_67943/children","parents":"https://data.bioontology.org/ontologies/CHEBI/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FCHEBI_67943/parents","descendants":"https://data.bioontology.org/ontologies/CHEBI/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FCHEBI_67943/descendants","ancestors":"https://data.bioontology.org/ontologies/CHEBI/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FCHEBI_67943/ancestors","instances":"https://data.bioontology.org/ontologies/CHEBI/ ...

# %%
# !curl "https://data.bioontology.org/ontologies/CHEBI/classes?page=1&apikey=87918894-263d-4f71-9b22-bfc345c1800d"
# Out:
# {"page":1,"pageCount":4417,"totalCount":220816,"prevPage":null,"nextPage":2,"links":{"nextPage":"https://data.bioontology.org/ontologies/CHEBI/classes?page=2&apikey=87918894-263d-4f71-9b22-bfc345c1800d","prevPage":null},"collection":[{"prefLabel":"CHEBI_23680","synonym":[],"definition":[],"cui":[],"semanticType":[],"obsolete":true,"@id":"http://purl.obolibrary.org/obo/CHEBI_23680","@type":"http://www.w3.org/2002/07/owl#Class","links":{"self":"https://data.bioontology.org/ontologies/CHEBI/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FCHEBI_23680","ontology":"https://data.bioontology.org/ontologies/CHEBI","children":"https://data.bioontology.org/ontologies/CHEBI/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FCHEBI_23680/children","parents":"https://data.bioontology.org/ontologies/CHEBI/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FCHEBI_23680/parents","descendants":"https://data.bioontology.org/ontologies/CHEBI/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FCHEBI_23680/descendants","ancestors":"https://data.bioontology.org/ontologies/CHEBI/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FCHEBI_23680/ancestors","instances":"https://data.bioontology.org/ontologies/CHEBI/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FCHEBI_23680/instances","tree":"https://data.bioontology.org/ontologies/CHEBI/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FCHEBI_23680/tree","notes":"https://data.bioontology.org/ontologies/CHEBI/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FCHEBI_23680/notes","mappings":"https://data.bioontology.org/ontologies/CHEBI/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FCHEBI_23680/mappings","ui":"http://bioportal.bioontology.org/ontologies/CHEBI?p=classes&conceptid=http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FCHEBI_23680","@context":{"self":"http://www.w3.org/2002/07/owl#Class","ontology":"http://data.bioontology.org/metadata/Ontology","children":"http://www.w3.org/2002/07/owl#Class","parents":"http://www.w3.org/2002/07/owl#Class","descendants":"http://www.w3.org/2002/07/owl#Class","ancestors":"http://www.w3.org/2002/07/owl#Class","instances":"http://data.bioontology.org/metadata/Instance","tree":"http://www.w3.org/2002/07/owl#Class","notes":"http://data.bioontology.org/metadata/Note","mappings":"http://data.bioontology.org/metadata/Mapping","ui":"http://www.w3.org/2002/07/owl#Class"}},"@context":{"@vocab":"http://data.bioontology.org/metadata/","prefLabel":"http://www.w3.org/2004/02/skos/core#prefLabel","synonym":"http://www.w3.org/2004/02/skos/core#altLabel","definition":"http://www.w3.org/2004/02/skos/core#definition","obsolete":"http://www.w3.org/2002/07/owl#deprecated","semanticType":"http://bioportal.bioontology.org/ontologies/umls/hasSTY","cui":"http://bioportal.bioontology.org/ontologies/umls/cui","@language":"en"}},{"prefLabel":"3beta,23-dihydroxyurs-12-en-28-oic acid 28-O-beta-D-glucopyranoside","synonym":["1-O-[3beta,23-dihydroxy-28-oxours-12-en-28-yl]-beta-D-glucopyranose"],"definition":["A triterpenoid saponin that is 28-O-beta-D-glucopyranosyl derivative of 23-hydroxyursolic acid. It has been isolated from the leaves and twigs of Juglans sinensis."],"cui":[],"semanticType":[],"obsolete":false,"@id":"http://purl.obolibrary.org/obo/CHEBI_67943","@type":"http://www.w3.org/2002/07/owl#Class","links":{"self":"https://data.bioontology.org/ontologies/CHEBI/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FCHEBI_67943","ontology":"https://data.bioontology.org/ontologies/CHEBI","children":"https://data.bioontology.org/ontologies/CHEBI/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FCHEBI_67943/children","parents":"https://data.bioontology.org/ontologies/CHEBI/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FCHEBI_67943/parents","descendants":"https://data.bioontology.org/ontologies/CHEBI/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FCHEBI_67943/descendants","ancestors":"https://data.bioontology.org/ontologies/CHEBI/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FCHEBI_67943/ancestors","instances":"ht ...

# %%
response = requests.get(BASE_URL, params={"page": 1, "apikey": "87918894-263d-4f71-9b22-bfc345c1800d"})

# %%
import requests
import json

API_KEY = "87918894-263d-4f71-9b22-bfc345c1800d"  # Replace with your actual API key
BASE_URL = "https://data.bioontology.org/ontologies/OBOE-SBC/classes"

def get_all_classes():
    """Fetches all classes (name + description) from the OBOE-SBC ontology using BioPortal API."""
    classes_dict = {}  # Dictionary to store class names and descriptions
    page = 1

    while True:
        response = requests.get(BASE_URL, params={"page": page, "apikey": API_KEY})

        if response.status_code != 200:
            print(f"❌ Error {response.status_code}: {response.text}")
            break

        data = response.json()

        if "collection" in data:
            ontology_classes = data["collection"]
        else:
            print("⚠️ Unexpected response structure. Check API response.")
            print(data)
            break

        if not ontology_classes:
            print("✅ No more data. Retrieval complete.")
            break

        # Extract class labels and descriptions
        for cls in ontology_classes:
            label = cls.get("prefLabel", "Unnamed")
            description = cls.get("definition", [""])
            if isinstance(description, list):  # Sometimes, definitions are lists
                description = description[0] if description else ""

            classes_dict[label] = description  # Store in dictionary

        print(f"📄 Fetched page {page}, total classes so far: {len(classes_dict)}")

        page += 1  # Move to the next page

    return classes_dict

# Run the function and get all classes
oboe_sbc_classes = get_all_classes()

# Print summary
print(f"🎉 Retrieved {len(oboe_sbc_classes)} classes from OBOE-SBC!")

# Save the data to a JSON file
json_filename = "oboe_sbc_classes.json"
with open(json_filename, "w", encoding="utf-8") as f:
    json.dump(oboe_sbc_classes, f, indent=2, ensure_ascii=False)

print(f"💾 Classes saved to '{json_filename}'")
# Out:
# 📄 Fetched page 1, total classes so far: 50
# 📄 Fetched page 2, total classes so far: 100
# 📄 Fetched page 3, total classes so far: 150
# 📄 Fetched page 4, total classes so far: 197
# 📄 Fetched page 5, total classes so far: 246
# 📄 Fetched page 6, total classes so far: 291
# 📄 Fetched page 7, total classes so far: 340
# 📄 Fetched page 8, total classes so far: 389
# 📄 Fetched page 9, total classes so far: 436
# 📄 Fetched page 10, total classes so far: 484
# 📄 Fetched page 11, total classes so far: 529
# 📄 Fetched page 12, total classes so far: 578
# 📄 Fetched page 13, total classes so far: 603
# ✅ No more data. Retrieval complete.
# 🎉 Retrieved 603 classes from OBOE-SBC!
# 💾 Classes saved to 'oboe_sbc_classes.json'

# %%
import requests
import json

API_KEY = "87918894-263d-4f71-9b22-bfc345c1800d"  # Replace with your actual API key
BASE_URL = "https://data.bioontology.org/ontologies/ENVO/classes"

def get_all_classes():
    """Fetches all classes (name + description) from the ENVO ontology using BioPortal API."""
    classes_dict = {}  # Dictionary to store class names and descriptions
    page = 1

    while True:
        response = requests.get(BASE_URL, params={"page": page, "apikey": API_KEY})

        if response.status_code != 200:
            print(f"❌ Error {response.status_code}: {response.text}")
            break

        data = response.json()

        if "collection" in data:
            ontology_classes = data["collection"]
        else:
            print("⚠️ Unexpected response structure. Check API response.")
            print(data)
            break

        if not ontology_classes:
            print("✅ No more data. Retrieval complete.")
            break

        # Extract class labels and descriptions
        for cls in ontology_classes:
            label = cls.get("prefLabel", "Unnamed")
            description = cls.get("definition", [""])
            if isinstance(description, list):  # Sometimes, definitions are lists
                description = description[0] if description else ""

            classes_dict[label] = description  # Store in dictionary

        print(f"📄 Fetched page {page}, total classes so far: {len(classes_dict)}")

        page += 1  # Move to the next page

    return classes_dict

# Run the function and get all classes
envo_classes = get_all_classes()

# Print summary
print(f"🎉 Retrieved {len(envo_classes)} classes from ENVO!")

# Save the data to a JSON file
json_filename = "envo_classes.json"
with open(json_filename, "w", encoding="utf-8") as f:
    json.dump(envo_classes, f, indent=2, ensure_ascii=False)

print(f"💾 Classes saved to '{json_filename}'")
# Out:
# 📄 Fetched page 1, total classes so far: 50
# 📄 Fetched page 2, total classes so far: 100
# 📄 Fetched page 3, total classes so far: 150
# 📄 Fetched page 4, total classes so far: 200
# 📄 Fetched page 5, total classes so far: 250
# 📄 Fetched page 6, total classes so far: 300
# 📄 Fetched page 7, total classes so far: 350
# 📄 Fetched page 8, total classes so far: 400
# 📄 Fetched page 9, total classes so far: 450
# 📄 Fetched page 10, total classes so far: 500
# 📄 Fetched page 11, total classes so far: 550
# 📄 Fetched page 12, total classes so far: 600
# 📄 Fetched page 13, total classes so far: 650
# 📄 Fetched page 14, total classes so far: 700
# 📄 Fetched page 15, total classes so far: 750
# 📄 Fetched page 16, total classes so far: 800
# 📄 Fetched page 17, total classes so far: 850
# 📄 Fetched page 18, total classes so far: 900
# 📄 Fetched page 19, total classes so far: 950
# 📄 Fetched page 20, total classes so far: 1000
# 📄 Fetched page 21, total classes so far: 1050
# 📄 Fetched page 22, total classes so far: 1100
# 📄 Fetched page 23, total classes so far: 1150
# 📄 Fetched page 24, total classes so far: 1200
# 📄 Fetched page 25, total classes so far: 1250
# 📄 Fetched page 26, total classes so far: 1300
# 📄 Fetched page 27, total classes so far: 1349
# 📄 Fetched page 28, total classes so far: 1399
# 📄 Fetched page 29, total classes so far: 1449
# 📄 Fetched page 30, total classes so far: 1499
# 📄 Fetched page 31, total classes so far: 1549
# 📄 Fetched page 32, total classes so far: 1599
# 📄 Fetched page 33, total classes so far: 1649
# 📄 Fetched page 34, total classes so far: 1699
# 📄 Fetched page 35, total classes so far: 1749
# 📄 Fetched page 36, total classes so far: 1799
# 📄 Fetched page 37, total classes so far: 1849
# 📄 Fetched page 38, total classes so far: 1899
# 📄 Fetched page 39, total classes so far: 1949
# 📄 Fetched page 40, total classes so far: 1999
# 📄 Fetched page 41, total classes so far: 2049
# 📄 Fetched page 42, total classes so far: 2099
# 📄 Fetched page 43, total classes so far: 2149
# 📄 Fetched page 44, total classes so far: 2198
# 📄 Fetched page 45, total classes so far: 2248
# 📄 Fetched page 46, total classes so far: 2298
# 📄 Fetched page 47, total classes so far: 2348
# 📄 Fetched page 48, total classes so far: 2398
# 📄 Fetched page 49, total classes so far: 2448
# 📄 Fetched page 50, total classes so far: 2498
# 📄 Fetched page 51, total classes so far: 2548
# 📄 Fetched page 52, total classes so far: 2598
# 📄 Fetched page 53, total classes so far: 2648
# 📄 Fetched page 54, total classes so far: 2698
# 📄 Fetched page 55, total classes so far: 2748
# 📄 Fetched page 56, total classes so far: 2798
# 📄 Fetched page 57, total classes so far: 2848
# 📄 Fetched page 58, total classes so far: 2898
# 📄 Fetched page 59, total classes so far: 2948
# 📄 Fetched page 60, total classes so far: 2998
# 📄 Fetched page 61, total classes so far: 3047
# 📄 Fetched page 62, total classes so far: 3097
# 📄 Fetched page 63, total classes so far: 3147
# 📄 Fetched page 64, total classes so far: 3197
# 📄 Fetched page 65, total classes so far: 3247
# 📄 Fetched page 66, total classes so far: 3297
# 📄 Fetched page 67, total classes so far: 3347
# 📄 Fetched page 68, total classes so far: 3397
# 📄 Fetched page 69, total classes so far: 3446
# 📄 Fetched page 70, total classes so far: 3496
# 📄 Fetched page 71, total classes so far: 3546
# 📄 Fetched page 72, total classes so far: 3596
# 📄 Fetched page 73, total classes so far: 3646
# 📄 Fetched page 74, total classes so far: 3696
# 📄 Fetched page 75, total classes so far: 3746
# 📄 Fetched page 76, total classes so far: 3796
# 📄 Fetched page 77, total classes so far: 3846
# 📄 Fetched page 78, total classes so far: 3896
# 📄 Fetched page 79, total classes so far: 3946
# 📄 Fetched page 80, total classes so far: 3996
# 📄 Fetched page 81, total classes so far: 4046
# 📄 Fetched page 82, total classes so far: 4096
# 📄 Fetched page 83, total classes so far: 4146
# 📄 Fetched page 84, total classes so far: 4196
# 📄 Fetched page 85, total classes so far: 4246
# 📄 Fetched page 86, total classes so far: 4296
# 📄 Fetched page 87, total classes so far: 4346
# 📄 Fetched page 88, total classes so far: 4395
# 📄 Fetched page 89, total classes so far: 4445
# 📄 Fetched page 90, total classes so far: 4495
# 📄 Fetched page 91, total classes so far: 4545
# 📄 Fetched page 92, total classes so far: 4595
# 📄 Fetched page 93, total classes so far: 4645
# 📄 Fetched page 94, total classes so far: 4695
# 📄 Fetched page 95, total classes so far: 4745
# 📄 Fetched page 96, total classes so far: 4795
# 📄 Fetched page 97, total classes so far: 4845
# 📄 Fetched page 98, total classes so far: 4894
# 📄 Fetched page 99, total classes so far: 4944
# 📄 Fetched page 100, total classes so far: 4993
# 📄 Fetched page 101, total classes so far: 5043
# 📄 Fetched page 102, total classes so far: 5093
# 📄 Fetched page 103, total classes so far: 5143
# 📄 Fetched page 104, total classes so far: 5193
# 📄 Fetched page 105, total classes so far: 5243
# 📄 Fetched page 106, total classes so far: 5293
# 📄 Fetched page 107, total classes so far: 5343
# 📄 Fetched page 108, total classes so far: 5393
# 📄 Fetched page 109, total classes so far: 5443
# 📄 Fetched page 110, total classes so far: 5493
# 📄 Fetched page 111, total classes so far: 5543
# 📄 Fetched page 112, total classes so far: 5593
# 📄 Fetched page 113, total classes so far: 5643
# 📄 Fetched page 114, total classes so far: 5693
# 📄 Fetched page 115, total classes so far: 5743
# 📄 Fetched page 116, total classes so far: 5793
# 📄 Fetched page 117, total classes so far: 5843
# 📄 Fetched page 118, total classes so far: 5893
# 📄 Fetched page 119, total classes so far: 5943
# 📄 Fetched page 120, total classes so far: 5993
# 📄 Fetched page 121, total classes so far: 6043
# 📄 Fetched page 122, total classes so far: 6093
# 📄 Fetched page 123, total classes so far: 6143
# 📄 Fetched page 124, total classes so far: 6193
# 📄 Fetched page 125, total classes so far: 6243
# 📄 Fetched page 126, total classes so far: 6293
# 📄 Fetched page 127, total classes so far: 6343
# 📄 Fetched page 128, total classes so far: 6393
# 📄 Fetched page 129, total classes so far: 6442
# 📄 Fetched page 130, total classes so far: 6492
# 📄 Fetched page 131, total classes so far: 6542
# 📄 Fetched page 132, total classes so far: 6592
# 📄 Fetched page 133, total classes so far: 6642
# 📄 Fetched page 134, total classes so far: 6692
# 📄 Fetched page 135, total classes so far: 6742
# 📄 Fetched page 136, total classes so far: 6792
# 📄 Fetched page 137, total classes so far: 6842
# 📄 Fetched page 138, total classes so far: 6892
# 📄 Fetched page 139, total classes so far: 6942
# 📄 Fetched page 140, total classes so far: 6992
# 📄 Fetched page 141, total classes so far: 7022
# ✅ No more data. Retrieval complete.
# 🎉 Retrieved 7022 classes from ENVO!
# 💾 Classes saved to 'envo_classes.json'

# %%
import requests
import json

API_KEY = "87918894-263d-4f71-9b22-bfc345c1800d"  # Replace with your actual API key
BASE_URL = "https://data.bioontology.org/ontologies/CHEBI/classes"

def get_all_classes():
    """Fetches all classes (name + description) from the ChEBI ontology using BioPortal API."""
    classes_dict = {}  # Dictionary to store class names and descriptions
    page = 1

    while True:
        response = requests.get(BASE_URL, params={"page": page, "apikey": API_KEY})

        if response.status_code != 200:
            print(f"❌ Error {response.status_code}: {response.text}")
            break

        data = response.json()

        if "collection" in data:
            ontology_classes = data["collection"]
        else:
            print("⚠️ Unexpected response structure. Check API response.")
            print(data)
            break

        if not ontology_classes:
            print("✅ No more data. Retrieval complete.")
            break

        # Extract class labels and descriptions
        for cls in ontology_classes:
            label = cls.get("prefLabel", "Unnamed")
            description = cls.get("definition", [""])
            if isinstance(description, list):  # Sometimes, definitions are lists
                description = description[0] if description else ""

            classes_dict[label] = description  # Store in dictionary

        print(f"📄 Fetched page {page}, total classes so far: {len(classes_dict)}")

        page += 1  # Move to the next page

    return classes_dict

# Run the function and get all classes
chebi_classes = get_all_classes()

# Print summary
print(f"🎉 Retrieved {len(chebi_classes)} classes from ChEBI!")

# Save the data to a JSON file
json_filename = "chebi_classes.json"
with open(json_filename, "w", encoding="utf-8") as f:
    json.dump(chebi_classes, f, indent=2, ensure_ascii=False)

print(f"💾 Classes saved to '{json_filename}'")
# Out:
# 📄 Fetched page 1, total classes so far: 50
# 📄 Fetched page 2, total classes so far: 100
# 📄 Fetched page 3, total classes so far: 150
# 📄 Fetched page 4, total classes so far: 200
# 📄 Fetched page 5, total classes so far: 250
# 📄 Fetched page 6, total classes so far: 300
# 📄 Fetched page 7, total classes so far: 350
# 📄 Fetched page 8, total classes so far: 400
# 📄 Fetched page 9, total classes so far: 450
# 📄 Fetched page 10, total classes so far: 500
# 📄 Fetched page 11, total classes so far: 550
# 📄 Fetched page 12, total classes so far: 600
# 📄 Fetched page 13, total classes so far: 650
# 📄 Fetched page 14, total classes so far: 700
# 📄 Fetched page 15, total classes so far: 750
# 📄 Fetched page 16, total classes so far: 800
# 📄 Fetched page 17, total classes so far: 850
# 📄 Fetched page 18, total classes so far: 900
# 📄 Fetched page 19, total classes so far: 950
# 📄 Fetched page 20, total classes so far: 1000
# 📄 Fetched page 21, total classes so far: 1050
# 📄 Fetched page 22, total classes so far: 1100
# 📄 Fetched page 23, total classes so far: 1150
# 📄 Fetched page 24, total classes so far: 1200
# 📄 Fetched page 25, total classes so far: 1250
# 📄 Fetched page 26, total classes so far: 1300
# 📄 Fetched page 27, total classes so far: 1350
# 📄 Fetched page 28, total classes so far: 1400
# 📄 Fetched page 29, total classes so far: 1450
# 📄 Fetched page 30, total classes so far: 1500
# 📄 Fetched page 31, total classes so far: 1550
# 📄 Fetched page 32, total classes so far: 1600
# 📄 Fetched page 33, total classes so far: 1650
# 📄 Fetched page 34, total classes so far: 1700
# 📄 Fetched page 35, total classes so far: 1750
# 📄 Fetched page 36, total classes so far: 1800
# 📄 Fetched page 37, total classes so far: 1850
# 📄 Fetched page 38, total classes so far: 1900
# 📄 Fetched page 39, total classes so far: 1950
# 📄 Fetched page 40, total classes so far: 2000
# 📄 Fetched page 41, total classes so far: 2050
# 📄 Fetched page 42, total classes so far: 2100
# 📄 Fetched page 43, total classes so far: 2150
# 📄 Fetched page 44, total classes so far: 2200
# 📄 Fetched page 45, total classes so far: 2250
# 📄 Fetched page 46, total classes so far: 2300
# 📄 Fetched page 47, total classes so far: 2350
# 📄 Fetched page 48, total classes so far: 2400
# 📄 Fetched page 49, total classes so far: 2450
# 📄 Fetched page 50, total classes so far: 2500
# 📄 Fetched page 51, total classes so far: 2550
# 📄 Fetched page 52, total classes so far: 2600
# 📄 Fetched page 53, total classes so far: 2650
# 📄 Fetched page 54, total classes so far: 2700
# 📄 Fetched page 55, total classes so far: 2750
# 📄 Fetched page 56, total classes so far: 2800
# 📄 Fetched page 57, total classes so far: 2850
# 📄 Fetched page 58, total classes so far: 2900
# 📄 Fetched page 59, total classes so far: 2950
# 📄 Fetched page 60, total classes so far: 3000
# 📄 Fetched page 61, total classes so far: 3050
# 📄 Fetched page 62, total classes so far: 3100
# 📄 Fetched page 63, total classes so far: 3150
# 📄 Fetched page 64, total classes so far: 3200
# 📄 Fetched page 65, total classes so far: 3250
# 📄 Fetched page 66, total classes so far: 3300
# 📄 Fetched page 67, total classes so far: 3350
# 📄 Fetched page 68, total classes so far: 3400
# 📄 Fetched page 69, total classes so far: 3450
# 📄 Fetched page 70, total classes so far: 3500
# 📄 Fetched page 71, total classes so far: 3550
# 📄 Fetched page 72, total classes so far: 3600
# 📄 Fetched page 73, total classes so far: 3650
# 📄 Fetched page 74, total classes so far: 3700
# 📄 Fetched page 75, total classes so far: 3750
# 📄 Fetched page 76, total classes so far: 3800
# 📄 Fetched page 77, total classes so far: 3850
# 📄 Fetched page 78, total classes so far: 3900
# 📄 Fetched page 79, total classes so far: 3950
# 📄 Fetched page 80, total classes so far: 4000
# 📄 Fetched page 81, total classes so far: 4050
# 📄 Fetched page 82, total classes so far: 4100
# 📄 Fetched page 83, total classes so far: 4150
# 📄 Fetched page 84, total classes so far: 4200
# 📄 Fetched page 85, total classes so far: 4250
# 📄 Fetched page 86, total classes so far: 4300
# 📄 Fetched page 87, total classes so far: 4350
# 📄 Fetched page 88, total classes so far: 4400
# 📄 Fetched page 89, total classes so far: 4450
# 📄 Fetched page 90, total classes so far: 4500
# 📄 Fetched page 91, total classes so far: 4550
# 📄 Fetched page 92, total classes so far: 4600
# 📄 Fetched page 93, total classes so far: 4650
# 📄 Fetched page 94, total classes so far: 4700
# 📄 Fetched page 95, total classes so far: 4750
# 📄 Fetched page 96, total classes so far: 4800
# 📄 Fetched page 97, total classes so far: 4850
# 📄 Fetched page 98, total classes so far: 4900
# 📄 Fetched page 99, total classes so far: 4950
# 📄 Fetched page 100, total classes so far: 5000
# 📄 Fetched page 101, total classes so far: 5050
# 📄 Fetched page 102, total classes so far: 5100
# 📄 Fetched page 103, total classes so far: 5150
# 📄 Fetched page 104, total classes so far: 5200
# 📄 Fetched page 105, total classes so far: 5250
# 📄 Fetched page 106, total classes so far: 5300
# 📄 Fetched page 107, total classes so far: 5350
# 📄 Fetched page 108, total classes so far: 5400
# 📄 Fetched page 109, total classes so far: 5450
# 📄 Fetched page 110, total classes so far: 5500
# 📄 Fetched page 111, total classes so far: 5550
# 📄 Fetched page 112, total classes so far: 5600
# 📄 Fetched page 113, total classes so far: 5650
# 📄 Fetched page 114, total classes so far: 5700
# 📄 Fetched page 115, total classes so far: 5750
# 📄 Fetched page 116, total classes so far: 5800
# 📄 Fetched page 117, total classes so far: 5850
# 📄 Fetched page 118, total classes so far: 5900
# 📄 Fetched page 119, total classes so far: 5950
# 📄 Fetched page 120, total classes so far: 6000
# 📄 Fetched page 121, total classes so far: 6050
# 📄 Fetched page 122, total classes so far: 6100
# 📄 Fetched page 123, total classes so far: 6150
# 📄 Fetched page 124, total classes so far: 6200
# 📄 Fetched page 125, total classes so far: 6250
# 📄 Fetched page 126, total classes so far: 6300
# 📄 Fetched page 127, total classes so far: 6350
# 📄 Fetched page 128, total classes so far: 6400
# 📄 Fetched page 129, total classes so far: 6450
# 📄 Fetched page 130, total classes so far: 6500
# 📄 Fetched page 131, total classes so far: 6550
# 📄 Fetched page 132, total classes so far: 6600
# 📄 Fetched page 133, total classes so far: 6650
# 📄 Fetched page 134, total classes so far: 6700
# 📄 Fetched page 135, total classes so far: 6750
# 📄 Fetched page 136, total classes so far: 6800
# 📄 Fetched page 137, total classes so far: 6850
# 📄 Fetched page 138, total classes so far: 6900
# 📄 Fetched page 139, total classes so far: 6950
# 📄 Fetched page 140, total classes so far: 7000
# 📄 Fetched page 141, total classes so far: 7050
# 📄 Fetched page 142, total classes so far: 7100
# 📄 Fetched page 143, total classes so far: 7150
# 📄 Fetched page 144, total classes so far: 7200
# 📄 Fetched page 145, total classes so far: 7250
# 📄 Fetched page 146, total classes so far: 7300
# 📄 Fetched page 147, total classes so far: 7350
# 📄 Fetched page 148, total classes so far: 7400
# 📄 Fetched page 149, total classes so far: 7450
# 📄 Fetched page 150, total classes so far: 7500
# 📄 Fetched page 151, total classes so far: 7550
# 📄 Fetched page 152, total classes so far: 7600
# 📄 Fetched page 153, total classes so far: 7650
# 📄 Fetched page 154, total classes so far: 7700
# 📄 Fetched page 155, total classes so far: 7750
# 📄 Fetched page 156, total classes so far: 7800
# 📄 Fetched page 157, total classes so far: 7850
# 📄 Fetched page 158, total classes so far: 7900
# 📄 Fetched page 159, total classes so far: 7950
# 📄 Fetched page 160, total classes so far: 8000
# 📄 Fetched page 161, total classes so far: 8050
# 📄 Fetched page 162, total classes so far: 8100
# 📄 Fetched page 163, total classes so far: 8150
# 📄 Fetched page 164, total classes so far: 8200
# 📄 Fetched page 165, total classes so far: 8250
# 📄 Fetched page 166, total classes so far: 8300
# 📄 Fetched page 167, total classes so far: 8350
# 📄 Fetched page 168, total classes so far: 8400
# 📄 Fetched page 169, total classes so far: 8450
# 📄 Fetched page 170, total classes so far: 8500
# 📄 Fetched page 171, total classes so far: 8550
# 📄 Fetched page 172, total classes so far: 8600
# 📄 Fetched page 173, total classes so far: 8650
# 📄 Fetched page 174, total classes so far: 8700
# 📄 Fetched page 175, total classes so far: 8750
# 📄 Fetched page 176, total classes so far: 8800
# 📄 Fetched page 177, total classes so far: 8850
# 📄 Fetched page 178, total classes so far: 8900
# 📄 Fetched page 179, total classes so far: 8950
# 📄 Fetched page 180, total classes so far: 9000
# 📄 Fetched page 181, total classes so far: 9050
# 📄 Fetched page 182, total classes so far: 9100
# 📄 Fetched page 183, total classes so far: 9150
# 📄 Fetched page 184, total classes so far: 9200
# 📄 Fetched page 185, total classes so far: 9250
# 📄 Fetched page 186, total classes so far: 9300
# 📄 Fetched page 187, total classes so far: 9350
# 📄 Fetched page 188, total classes so far: 9400
# 📄 Fetched page 189, total classes so far: 9450
# 📄 Fetched page 190, total classes so far: 9500
# 📄 Fetched page 191, total classes so far: 9550
# 📄 Fetched page 192, total classes so far: 9600
# 📄 Fetched page 193, total classes so far: 9650
# 📄 Fetched page 194, total classes so far: 9700
# 📄 Fetched page 195, total classes so far: 9750
# 📄 Fetched page 196, total classes so far: 9800
# 📄 Fetched page 197, total classes so far: 9850
# 📄 Fetched page 198, total classes so far: 9900
# 📄 Fetched page 199, total classes so far: 9950
# 📄 Fetched page 200, total classes so far: 10000
# 📄 Fetched page 201, total classes so far: 10050
# 📄 Fetched page 202, total classes so far: 10100
# 📄 Fetched page 203, total classes so far: 10150
# 📄 Fetched page 204, total classes so far: 10200
# 📄 Fetched page 205, total classes so far: 10250
# 📄 Fetched page 206, total classes so far: 10300
# 📄 Fetched page 207, total classes so far: 10350
# 📄 Fetched page 208, total classes so far: 10400
# 📄 Fetched page 209, total classes so far: 10450
# 📄 Fetched page 210, total classes so far: 10500
# 📄 Fetched page 211, total classes so far: 10550
# 📄 Fetched page 212, total classes so far: 10600
# 📄 Fetched page 213, total classes so far: 10650
# 📄 Fetched page 214, total classes so far: 10700
# 📄 Fetched page 215, total classes so far: 10750
# 📄 Fetched page 216, total classes so far: 10800
# 📄 Fetched page 217, total classes so far: 10850
# 📄 Fetched page 218, total classes so far: 10900
# 📄 Fetched page 219, total classes so far: 10950
# 📄 Fetched page 220, total classes so far: 11000
# 📄 Fetched page 221, total classes so far: 11050
# 📄 Fetched page 222, total classes so far: 11100
# 📄 Fetched page 223, total classes so far: 11150
# 📄 Fetched page 224, total classes so far: 11200
# 📄 Fetched page 225, total classes so far: 11250
# 📄 Fetched page 226, total classes so far: 11300
# 📄 Fetched page 227, total classes so far: 11350
# 📄 Fetched page 228, total classes so far: 11400
# 📄 Fetched page 229, total classes so far: 11450
# 📄 Fetched page 230, total classes so far: 11500
# 📄 Fetched page 231, total classes so far: 11550
# 📄 Fetched page 232, total classes so far: 11600
# 📄 Fetched page 233, total classes so far: 11650
# 📄 Fetched page 234, total classes so far: 11700
# 📄 Fetched page 235, total classes so far: 11750
# 📄 Fetched page 236, total classes so far: 11800
# 📄 Fetched page 237, total classes so far: 11850
# 📄 Fetched page 238, total classes so far: 11900
# 📄 Fetched page 239, total classes so far: 11950
# 📄 Fetched page 240, total classes so far: 12000
# 📄 Fetched page 241, total classes so far: 12050
# 📄 Fetched page 242, total classes so far: 12100
# 📄 Fetched page 243, total classes so far: 12150
# 📄 Fetched page 244, total classes so far: 12200
# 📄 Fetched page 245, total classes so far: 12250
# 📄 Fetched page 246, total classes so far: 12300
# 📄 Fetched page 247, total classes so far: 12350
# 📄 Fetched page 248, total classes so far: 12400
# 📄 Fetched page 249, total classes so far: 12450
# 📄 Fetched page 250, total classes so far: 12500
# 📄 Fetched page 251, total classes so far: 12550
# 📄 Fetched page 252, total classes so far: 12600
# 📄 Fetched page 253, total classes so far: 12650
# 📄 Fetched page 254, total classes so far: 12700
# 📄 Fetched page 255, total classes so far: 12750
# 📄 Fetched page 256, total classes so far: 12800
# 📄 Fetched page 257, total classes so far: 12850
# 📄 Fetched page 258, total classes so far: 12900
# 📄 Fetched page 259, total classes so far: 12950
# 📄 Fetched page 260, total classes so far: 13000
# 📄 Fetched page 261, total classes so far: 13050
# 📄 Fetched page 262, total classes so far: 13100
# 📄 Fetched page 263, total classes so far: 13150
# 📄 Fetched page 264, total classes so far: 13200
# 📄 Fetched page 265, total classes so far: 13250
# 📄 Fetched page 266, total classes so far: 13300
# 📄 Fetched page 267, total classes so far: 13350
# 📄 Fetched page 268, total classes so far: 13400
# 📄 Fetched page 269, total classes so far: 13450
# 📄 Fetched page 270, total classes so far: 13500
# 📄 Fetched page 271, total classes so far: 13550
# 📄 Fetched page 272, total classes so far: 13600
# 📄 Fetched page 273, total classes so far: 13650
# 📄 Fetched page 274, total classes so far: 13700
# 📄 Fetched page 275, total classes so far: 13750
# 📄 Fetched page 276, total classes so far: 13800
# 📄 Fetched page 277, total classes so far: 13850
# 📄 Fetched page 278, total classes so far: 13900
# 📄 Fetched page 279, total classes so far: 13950
# 📄 Fetched page 280, total classes so far: 14000
# 📄 Fetched page 281, total classes so far: 14050
# 📄 Fetched page 282, total classes so far: 14100
# 📄 Fetched page 283, total classes so far: 14150
# 📄 Fetched page 284, total classes so far: 14200
# 📄 Fetched page 285, total classes so far: 14250
# 📄 Fetched page 286, total classes so far: 14300
# 📄 Fetched page 287, total classes so far: 14350
# 📄 Fetched page 288, total classes so far: 14400
# 📄 Fetched page 289, total classes so far: 14450
# 📄 Fetched page 290, total classes so far: 14500
# 📄 Fetched page 291, total classes so far: 14550
# 📄 Fetched page 292, total classes so far: 14600
# 📄 Fetched page 293, total classes so far: 14650
# 📄 Fetched page 294, total classes so far: 14700
# 📄 Fetched page 295, total classes so far: 14750
# 📄 Fetched page 296, total classes so far: 14800
# 📄 Fetched page 297, total classes so far: 14850
# 📄 Fetched page 298, total classes so far: 14900
# 📄 Fetched page 299, total classes so far: 14950
# 📄 Fetched page 300, total classes so far: 15000
# 📄 Fetched page 301, total classes so far: 15050
# 📄 Fetched page 302, total classes so far: 15100
# 📄 Fetched page 303, total classes so far: 15150
# 📄 Fetched page 304, total classes so far: 15200
# 📄 Fetched page 305, total classes so far: 15250
# 📄 Fetched page 306, total classes so far: 15300
# 📄 Fetched page 307, total classes so far: 15350
# 📄 Fetched page 308, total classes so far: 15400
# 📄 Fetched page 309, total classes so far: 15450
# 📄 Fetched page 310, total classes so far: 15500
# 📄 Fetched page 311, total classes so far: 15550
# 📄 Fetched page 312, total classes so far: 15600
# 📄 Fetched page 313, total classes so far: 15650
# 📄 Fetched page 314, total classes so far: 15700
# 📄 Fetched page 315, total classes so far: 15750
# 📄 Fetched page 316, total classes so far: 15800
# 📄 Fetched page 317, total classes so far: 15850
# 📄 Fetched page 318, total classes so far: 15900
# 📄 Fetched page 319, total classes so far: 15950
# 📄 Fetched page 320, total classes so far: 16000
# 📄 Fetched page 321, total classes so far: 16050
# 📄 Fetched page 322, total classes so far: 16100
# 📄 Fetched page 323, total classes so far: 16150
# 📄 Fetched page 324, total classes so far: 16200
# 📄 Fetched page 325, total classes so far: 16250
# 📄 Fetched page 326, total classes so far: 16300
# 📄 Fetched page 327, total classes so far: 16350
# 📄 Fetched page 328, total classes so far: 16400
# 📄 Fetched page 329, total classes so far: 16450
# 📄 Fetched page 330, total classes so far: 16500
# 📄 Fetched page 331, total classes so far: 16550
# 📄 Fetched page 332, total classes so far: 16600
# 📄 Fetched page 333, total classes so far: 16650
# 📄 Fetched page 334, total classes so far: 16700
# 📄 Fetched page 335, total classes so far: 16750
# 📄 Fetched page 336, total classes so far: 16800
# 📄 Fetched page 337, total classes so far: 16850
# 📄 Fetched page 338, total classes so far: 16900
# 📄 Fetched page 339, total classes so far: 16950
# 📄 Fetched page 340, total classes so far: 17000
# 📄 Fetched page 341, total classes so far: 17050
# 📄 Fetched page 342, total classes so far: 17100
# 📄 Fetched page 343, total classes so far: 17150
# 📄 Fetched page 344, total classes so far: 17200
# 📄 Fetched page 345, total classes so far: 17250
# 📄 Fetched page 346, total classes so far: 17300
# 📄 Fetched page 347, total classes so far: 17350
# 📄 Fetched page 348, total classes so far: 17400
# 📄 Fetched page 349, total classes so far: 17450
# 📄 Fetched page 350, total classes so far: 17500
# 📄 Fetched page 351, total classes so far: 17550
# 📄 Fetched page 352, total classes so far: 17600
# 📄 Fetched page 353, total classes so far: 17650
# 📄 Fetched page 354, total classes so far: 17700
# 📄 Fetched page 355, total classes so far: 17750
# 📄 Fetched page 356, total classes so far: 17800
# 📄 Fetched page 357, total classes so far: 17850
# 📄 Fetched page 358, total classes so far: 17900
# 📄 Fetched page 359, total classes so far: 17950
# 📄 Fetched page 360, total classes so far: 18000
# 📄 Fetched page 361, total classes so far: 18050
# 📄 Fetched page 362, total classes so far: 18100
# 📄 Fetched page 363, total classes so far: 18150
# 📄 Fetched page 364, total classes so far: 18200
# 📄 Fetched page 365, total classes so far: 18250
# 📄 Fetched page 366, total classes so far: 18300
# 📄 Fetched page 367, total classes so far: 18350
# 📄 Fetched page 368, total classes so far: 18400
# 📄 Fetched page 369, total classes so far: 18450
# 📄 Fetched page 370, total classes so far: 18500
# 📄 Fetched page 371, total classes so far: 18550
# 📄 Fetched page 372, total classes so far: 18600
# 📄 Fetched page 373, total classes so far: 18650
# 📄 Fetched page 374, total classes so far: 18700
# 📄 Fetched page 375, total classes so far: 18750
# 📄 Fetched page 376, total classes so far: 18800
# 📄 Fetched page 377, total classes so far: 18850
# 📄 Fetched page 378, total classes so far: 18900
# 📄 Fetched page 379, total classes so far: 18950
# 📄 Fetched page 380, total classes so far: 19000
# 📄 Fetched page 381, total classes so far: 19050
# 📄 Fetched page 382, total classes so far: 19100
# 📄 Fetched page 383, total classes so far: 19150
# 📄 Fetched page 384, total classes so far: 19200
# 📄 Fetched page 385, total classes so far: 19250
# 📄 Fetched page 386, total classes so far: 19300
# 📄 Fetched page 387, total classes so far: 19350
# 📄 Fetched page 388, total classes so far: 19400
# 📄 Fetched page 389, total classes so far: 19450
# 📄 Fetched page 390, total classes so far: 19500
# 📄 Fetched page 391, total classes so far: 19550
# 📄 Fetched page 392, total classes so far: 19600
# 📄 Fetched page 393, total classes so far: 19650
# 📄 Fetched page 394, total classes so far: 19700
# 📄 Fetched page 395, total classes so far: 19750
# 📄 Fetched page 396, total classes so far: 19800
# 📄 Fetched page 397, total classes so far: 19850
# 📄 Fetched page 398, total classes so far: 19900
# 📄 Fetched page 399, total classes so far: 19950
# 📄 Fetched page 400, total classes so far: 20000
# 📄 Fetched page 401, total classes so far: 20050
# 📄 Fetched page 402, total classes so far: 20100
# 📄 Fetched page 403, total classes so far: 20150
# 📄 Fetched page 404, total classes so far: 20200
# 📄 Fetched page 405, total classes so far: 20250
# 📄 Fetched page 406, total classes so far: 20300
# 📄 Fetched page 407, total classes so far: 20350
# 📄 Fetched page 408, total classes so far: 20400
# 📄 Fetched page 409, total classes so far: 20450
# 📄 Fetched page 410, total classes so far: 20500
# 📄 Fetched page 411, total classes so far: 20550
# 📄 Fetched page 412, total classes so far: 20600
# 📄 Fetched page 413, total classes so far: 20650
# 📄 Fetched page 414, total classes so far: 20700
# 📄 Fetched page 415, total classes so far: 20750
# 📄 Fetched page 416, total classes so far: 20800
# 📄 Fetched page 417, total classes so far: 20850
# 📄 Fetched page 418, total classes so far: 20900
# 📄 Fetched page 419, total classes so far: 20950
# 📄 Fetched page 420, total classes so far: 21000
# 📄 Fetched page 421, total classes so far: 21050
# 📄 Fetched page 422, total classes so far: 21100
# 📄 Fetched page 423, total classes so far: 21150
# 📄 Fetched page 424, total classes so far: 21200
# 📄 Fetched page 425, total classes so far: 21250
# 📄 Fetched page 426, total classes so far: 21300
# 📄 Fetched page 427, total classes so far: 21350
# 📄 Fetched page 428, total classes so far: 21400
# 📄 Fetched page 429, total classes so far: 21450
# 📄 Fetched page 430, total classes so far: 21500
# 📄 Fetched page 431, total classes so far: 21550
# 📄 Fetched page 432, total classes so far: 21600
# 📄 Fetched page 433, total classes so far: 21650
# 📄 Fetched page 434, total classes so far: 21700
# 📄 Fetched page 435, total classes so far: 21750
# 📄 Fetched page 436, total classes so far: 21800
# 📄 Fetched page 437, total classes so far: 21850
# 📄 Fetched page 438, total classes so far: 21900
# 📄 Fetched page 439, total classes so far: 21950
# 📄 Fetched page 440, total classes so far: 22000
# 📄 Fetched page 441, total classes so far: 22050
# 📄 Fetched page 442, total classes so far: 22100
# 📄 Fetched page 443, total classes so far: 22150
# 📄 Fetched page 444, total classes so far: 22200
# 📄 Fetched page 445, total classes so far: 22250
# 📄 Fetched page 446, total classes so far: 22300
# 📄 Fetched page 447, total classes so far: 22350
# 📄 Fetched page 448, total classes so far: 22400
# 📄 Fetched page 449, total classes so far: 22450
# 📄 Fetched page 450, total classes so far: 22500
# 📄 Fetched page 451, total classes so far: 22550
# 📄 Fetched page 452, total classes so far: 22600
# 📄 Fetched page 453, total classes so far: 22650
# 📄 Fetched page 454, total classes so far: 22700
# 📄 Fetched page 455, total classes so far: 22750
# 📄 Fetched page 456, total classes so far: 22800
# 📄 Fetched page 457, total classes so far: 22850
# 📄 Fetched page 458, total classes so far: 22900
# 📄 Fetched page 459, total classes so far: 22950
# 📄 Fetched page 460, total classes so far: 23000
# 📄 Fetched page 461, total classes so far: 23050
# 📄 Fetched page 462, total classes so far: 23100
# 📄 Fetched page 463, total classes so far: 23150
# 📄 Fetched page 464, total classes so far: 23200
# 📄 Fetched page 465, total classes so far: 23250
# 📄 Fetched page 466, total classes so far: 23300
# 📄 Fetched page 467, total classes so far: 23350
# 📄 Fetched page 468, total classes so far: 23400
# 📄 Fetched page 469, total classes so far: 23450
# 📄 Fetched page 470, total classes so far: 23500
# 📄 Fetched page 471, total classes so far: 23550
# 📄 Fetched page 472, total classes so far: 23600
# 📄 Fetched page 473, total classes so far: 23650
# 📄 Fetched page 474, total classes so far: 23700
# 📄 Fetched page 475, total classes so far: 23750
# 📄 Fetched page 476, total classes so far: 23800
# 📄 Fetched page 477, total classes so far: 23850
# 📄 Fetched page 478, total classes so far: 23900
# 📄 Fetched page 479, total classes so far: 23950
# 📄 Fetched page 480, total classes so far: 24000
# 📄 Fetched page 481, total classes so far: 24050
# 📄 Fetched page 482, total classes so far: 24100
# 📄 Fetched page 483, total classes so far: 24150
# 📄 Fetched page 484, total classes so far: 24200
# 📄 Fetched page 485, total classes so far: 24250
# 📄 Fetched page 486, total classes so far: 24300
# 📄 Fetched page 487, total classes so far: 24350
# 📄 Fetched page 488, total classes so far: 24400
# 📄 Fetched page 489, total classes so far: 24450
# 📄 Fetched page 490, total classes so far: 24500
# 📄 Fetched page 491, total classes so far: 24550
# 📄 Fetched page 492, total classes so far: 24600
# 📄 Fetched page 493, total classes so far: 24650
# 📄 Fetched page 494, total classes so far: 24700
# 📄 Fetched page 495, total classes so far: 24750
# 📄 Fetched page 496, total classes so far: 24800
# 📄 Fetched page 497, total classes so far: 24850
# 📄 Fetched page 498, total classes so far: 24900
# 📄 Fetched page 499, total classes so far: 24950
# 📄 Fetched page 500, total classes so far: 25000
# 📄 Fetched page 501, total classes so far: 25050
# 📄 Fetched page 502, total classes so far: 25100
# 📄 Fetched page 503, total classes so far: 25150
# 📄 Fetched page 504, total classes so far: 25200
# 📄 Fetched page 505, total classes so far: 25250
# 📄 Fetched page 506, total classes so far: 25300
# 📄 Fetched page 507, total classes so far: 25350
# 📄 Fetched page 508, total classes so far: 25400
# 📄 Fetched page 509, total classes so far: 25450
# 📄 Fetched page 510, total classes so far: 25500
# 📄 Fetched page 511, total classes so far: 25550
# 📄 Fetched page 512, total classes so far: 25600
# 📄 Fetched page 513, total classes so far: 25650
# 📄 Fetched page 514, total classes so far: 25700
# 📄 Fetched page 515, total classes so far: 25750
# 📄 Fetched page 516, total classes so far: 25800
# 📄 Fetched page 517, total classes so far: 25850
# 📄 Fetched page 518, total classes so far: 25900
# 📄 Fetched page 519, total classes so far: 25950
# 📄 Fetched page 520, total classes so far: 26000
# 📄 Fetched page 521, total classes so far: 26050
# 📄 Fetched page 522, total classes so far: 26100
# 📄 Fetched page 523, total classes so far: 26150
# 📄 Fetched page 524, total classes so far: 26200
# 📄 Fetched page 525, total classes so far: 26250
# 📄 Fetched page 526, total classes so far: 26300
# 📄 Fetched page 527, total classes so far: 26350
# 📄 Fetched page 528, total classes so far: 26400
# 📄 Fetched page 529, total classes so far: 26450
# 📄 Fetched page 530, total classes so far: 26500
# 📄 Fetched page 531, total classes so far: 26550
# 📄 Fetched page 532, total classes so far: 26600
# 📄 Fetched page 533, total classes so far: 26650
# 📄 Fetched page 534, total classes so far: 26700
# 📄 Fetched page 535, total classes so far: 26750
# 📄 Fetched page 536, total classes so far: 26800
# 📄 Fetched page 537, total classes so far: 26850
# 📄 Fetched page 538, total classes so far: 26900
# 📄 Fetched page 539, total classes so far: 26950
# 📄 Fetched page 540, total classes so far: 27000
# 📄 Fetched page 541, total classes so far: 27050
# 📄 Fetched page 542, total classes so far: 27100
# 📄 Fetched page 543, total classes so far: 27150
# 📄 Fetched page 544, total classes so far: 27200
# 📄 Fetched page 545, total classes so far: 27250
# 📄 Fetched page 546, total classes so far: 27300
# 📄 Fetched page 547, total classes so far: 27350
# 📄 Fetched page 548, total classes so far: 27400
# 📄 Fetched page 549, total classes so far: 27450
# 📄 Fetched page 550, total classes so far: 27500
# 📄 Fetched page 551, total classes so far: 27550
# 📄 Fetched page 552, total classes so far: 27600
# 📄 Fetched page 553, total classes so far: 27650
# 📄 Fetched page 554, total classes so far: 27700
# 📄 Fetched page 555, total classes so far: 27750
# 📄 Fetched page 556, total classes so far: 27800
# 📄 Fetched page 557, total classes so far: 27850
# 📄 Fetched page 558, total classes so far: 27900
# 📄 Fetched page 559, total classes so far: 27950
# 📄 Fetched page 560, total classes so far: 28000
# 📄 Fetched page 561, total classes so far: 28050
# 📄 Fetched page 562, total classes so far: 28100
# 📄 Fetched page 563, total classes so far: 28150
# 📄 Fetched page 564, total classes so far: 28200
# 📄 Fetched page 565, total classes so far: 28250
# 📄 Fetched page 566, total classes so far: 28300
# 📄 Fetched page 567, total classes so far: 28350
# 📄 Fetched page 568, total classes so far: 28400
# 📄 Fetched page 569, total classes so far: 28450
# 📄 Fetched page 570, total classes so far: 28500
# 📄 Fetched page 571, total classes so far: 28550
# 📄 Fetched page 572, total classes so far: 28600
# 📄 Fetched page 573, total classes so far: 28650
# 📄 Fetched page 574, total classes so far: 28700
# 📄 Fetched page 575, total classes so far: 28750
# 📄 Fetched page 576, total classes so far: 28800
# 📄 Fetched page 577, total classes so far: 28850
# 📄 Fetched page 578, total classes so far: 28900
# 📄 Fetched page 579, total classes so far: 28950
# 📄 Fetched page 580, total classes so far: 29000
# 📄 Fetched page 581, total classes so far: 29050
# 📄 Fetched page 582, total classes so far: 29100
# 📄 Fetched page 583, total classes so far: 29150
# 📄 Fetched page 584, total classes so far: 29200
# 📄 Fetched page 585, total classes so far: 29250
# 📄 Fetched page 586, total classes so far: 29300
# 📄 Fetched page 587, total classes so far: 29350
# 📄 Fetched page 588, total classes so far: 29400
# 📄 Fetched page 589, total classes so far: 29450
# 📄 Fetched page 590, total classes so far: 29500
# 📄 Fetched page 591, total classes so far: 29550
# 📄 Fetched page 592, total classes so far: 29600
# 📄 Fetched page 593, total classes so far: 29650
# 📄 Fetched page 594, total classes so far: 29700
# 📄 Fetched page 595, total classes so far: 29750
# 📄 Fetched page 596, total classes so far: 29800
# 📄 Fetched page 597, total classes so far: 29850
# 📄 Fetched page 598, total classes so far: 29900
# 📄 Fetched page 599, total classes so far: 29950
# 📄 Fetched page 600, total classes so far: 30000
# 📄 Fetched page 601, total classes so far: 30050
# 📄 Fetched page 602, total classes so far: 30100
# 📄 Fetched page 603, total classes so far: 30150
# 📄 Fetched page 604, total classes so far: 30200
# 📄 Fetched page 605, total classes so far: 30250
# 📄 Fetched page 606, total classes so far: 30300
# 📄 Fetched page 607, total classes so far: 30350
# 📄 Fetched page 608, total classes so far: 30400
# 📄 Fetched page 609, total classes so far: 30450
# 📄 Fetched page 610, total classes so far: 30500
# 📄 Fetched page 611, total classes so far: 30550
# 📄 Fetched page 612, total classes so far: 30600
# 📄 Fetched page 613, total classes so far: 30650
# 📄 Fetched page 614, total classes so far: 30700
# 📄 Fetched page 615, total classes so far: 30750
# 📄 Fetched page 616, total classes so far: 30800
# 📄 Fetched page 617, total classes so far: 30850
# 📄 Fetched page 618, total classes so far: 30900
# 📄 Fetched page 619, total classes so far: 30950
# 📄 Fetched page 620, total classes so far: 31000
# 📄 Fetched page 621, total classes so far: 31050
# 📄 Fetched page 622, total classes so far: 31100
# 📄 Fetched page 623, total classes so far: 31150
# 📄 Fetched page 624, total classes so far: 31200
# 📄 Fetched page 625, total classes so far: 31250
# 📄 Fetched page 626, total classes so far: 31300
# 📄 Fetched page 627, total classes so far: 31350
# 📄 Fetched page 628, total classes so far: 31400
# 📄 Fetched page 629, total classes so far: 31450
# 📄 Fetched page 630, total classes so far: 31500
# 📄 Fetched page 631, total classes so far: 31550
# 📄 Fetched page 632, total classes so far: 31600
# 📄 Fetched page 633, total classes so far: 31650
# 📄 Fetched page 634, total classes so far: 31700
# 📄 Fetched page 635, total classes so far: 31750
# 📄 Fetched page 636, total classes so far: 31800
# 📄 Fetched page 637, total classes so far: 31850
# 📄 Fetched page 638, total classes so far: 31900
# 📄 Fetched page 639, total classes so far: 31950
# 📄 Fetched page 640, total classes so far: 32000
# 📄 Fetched page 641, total classes so far: 32050
# 📄 Fetched page 642, total classes so far: 32100
# 📄 Fetched page 643, total classes so far: 32150
# 📄 Fetched page 644, total classes so far: 32200
# 📄 Fetched page 645, total classes so far: 32250
# 📄 Fetched page 646, total classes so far: 32300
# 📄 Fetched page 647, total classes so far: 32350
# 📄 Fetched page 648, total classes so far: 32400
# 📄 Fetched page 649, total classes so far: 32450
# 📄 Fetched page 650, total classes so far: 32500
# 📄 Fetched page 651, total classes so far: 32550
# 📄 Fetched page 652, total classes so far: 32600
# 📄 Fetched page 653, total classes so far: 32650
# 📄 Fetched page 654, total classes so far: 32700
# 📄 Fetched page 655, total classes so far: 32750
# 📄 Fetched page 656, total classes so far: 32800
# 📄 Fetched page 657, total classes so far: 32850
# 📄 Fetched page 658, total classes so far: 32900
# 📄 Fetched page 659, total classes so far: 32950
# 📄 Fetched page 660, total classes so far: 33000
# 📄 Fetched page 661, total classes so far: 33050
# 📄 Fetched page 662, total classes so far: 33100
# 📄 Fetched page 663, total classes so far: 33150
# 📄 Fetched page 664, total classes so far: 33200
# 📄 Fetched page 665, total classes so far: 33250
# 📄 Fetched page 666, total classes so far: 33300
# 📄 Fetched page 667, total classes so far: 33350
# 📄 Fetched page 668, total classes so far: 33400
# 📄 Fetched page 669, total classes so far: 33450
# 📄 Fetched page 670, total classes so far: 33500
# 📄 Fetched page 671, total classes so far: 33550
# 📄 Fetched page 672, total classes so far: 33600
# 📄 Fetched page 673, total classes so far: 33650
# 📄 Fetched page 674, total classes so far: 33700
# 📄 Fetched page 675, total classes so far: 33750
# 📄 Fetched page 676, total classes so far: 33800
# 📄 Fetched page 677, total classes so far: 33850
# 📄 Fetched page 678, total classes so far: 33900
# 📄 Fetched page 679, total classes so far: 33950
# 📄 Fetched page 680, total classes so far: 34000
# 📄 Fetched page 681, total classes so far: 34050
# 📄 Fetched page 682, total classes so far: 34100
# 📄 Fetched page 683, total classes so far: 34150
# 📄 Fetched page 684, total classes so far: 34200
# 📄 Fetched page 685, total classes so far: 34250
# 📄 Fetched page 686, total classes so far: 34300
# 📄 Fetched page 687, total classes so far: 34350
# 📄 Fetched page 688, total classes so far: 34400
# 📄 Fetched page 689, total classes so far: 34450
# 📄 Fetched page 690, total classes so far: 34500
# 📄 Fetched page 691, total classes so far: 34550
# 📄 Fetched page 692, total classes so far: 34600
# 📄 Fetched page 693, total classes so far: 34650
# 📄 Fetched page 694, total classes so far: 34700
# 📄 Fetched page 695, total classes so far: 34750
# 📄 Fetched page 696, total classes so far: 34800
# 📄 Fetched page 697, total classes so far: 34850
# 📄 Fetched page 698, total classes so far: 34900
# 📄 Fetched page 699, total classes so far: 34950
# 📄 Fetched page 700, total classes so far: 35000
# 📄 Fetched page 701, total classes so far: 35050
# 📄 Fetched page 702, total classes so far: 35100
# 📄 Fetched page 703, total classes so far: 35150
# 📄 Fetched page 704, total classes so far: 35200
# 📄 Fetched page 705, total classes so far: 35250
# 📄 Fetched page 706, total classes so far: 35300
# 📄 Fetched page 707, total classes so far: 35350
# 📄 Fetched page 708, total classes so far: 35400
# 📄 Fetched page 709, total classes so far: 35450
# 📄 Fetched page 710, total classes so far: 35500
# 📄 Fetched page 711, total classes so far: 35550
# 📄 Fetched page 712, total classes so far: 35600
# 📄 Fetched page 713, total classes so far: 35650
# 📄 Fetched page 714, total classes so far: 35700
# 📄 Fetched page 715, total classes so far: 35750
# 📄 Fetched page 716, total classes so far: 35800
# 📄 Fetched page 717, total classes so far: 35850
# 📄 Fetched page 718, total classes so far: 35900
# 📄 Fetched page 719, total classes so far: 35950
# 📄 Fetched page 720, total classes so far: 36000
# 📄 Fetched page 721, total classes so far: 36050
# 📄 Fetched page 722, total classes so far: 36100
# 📄 Fetched page 723, total classes so far: 36150
# 📄 Fetched page 724, total classes so far: 36200
# 📄 Fetched page 725, total classes so far: 36250
# 📄 Fetched page 726, total classes so far: 36300
# 📄 Fetched page 727, total classes so far: 36350
# 📄 Fetched page 728, total classes so far: 36400
# 📄 Fetched page 729, total classes so far: 36450
# 📄 Fetched page 730, total classes so far: 36500
# 📄 Fetched page 731, total classes so far: 36550
# 📄 Fetched page 732, total classes so far: 36600
# 📄 Fetched page 733, total classes so far: 36650
# 📄 Fetched page 734, total classes so far: 36700
# 📄 Fetched page 735, total classes so far: 36750
# 📄 Fetched page 736, total classes so far: 36800
# 📄 Fetched page 737, total classes so far: 36850
# 📄 Fetched page 738, total classes so far: 36900
# 📄 Fetched page 739, total classes so far: 36950
# 📄 Fetched page 740, total classes so far: 37000
# 📄 Fetched page 741, total classes so far: 37050
# 📄 Fetched page 742, total classes so far: 37100
# 📄 Fetched page 743, total classes so far: 37150
# 📄 Fetched page 744, total classes so far: 37200
# 📄 Fetched page 745, total classes so far: 37250
# 📄 Fetched page 746, total classes so far: 37300
# 📄 Fetched page 747, total classes so far: 37350
# 📄 Fetched page 748, total classes so far: 37400
# 📄 Fetched page 749, total classes so far: 37450
# 📄 Fetched page 750, total classes so far: 37500
# 📄 Fetched page 751, total classes so far: 37550
# 📄 Fetched page 752, total classes so far: 37600
# 📄 Fetched page 753, total classes so far: 37650
# 📄 Fetched page 754, total classes so far: 37700
# 📄 Fetched page 755, total classes so far: 37750
# 📄 Fetched page 756, total classes so far: 37800
# 📄 Fetched page 757, total classes so far: 37850
# 📄 Fetched page 758, total classes so far: 37900
# 📄 Fetched page 759, total classes so far: 37950
# 📄 Fetched page 760, total classes so far: 38000
# 📄 Fetched page 761, total classes so far: 38050
# 📄 Fetched page 762, total classes so far: 38100
# 📄 Fetched page 763, total classes so far: 38150
# 📄 Fetched page 764, total classes so far: 38200
# 📄 Fetched page 765, total classes so far: 38250
# 📄 Fetched page 766, total classes so far: 38300
# 📄 Fetched page 767, total classes so far: 38350
# 📄 Fetched page 768, total classes so far: 38400
# 📄 Fetched page 769, total classes so far: 38450
# 📄 Fetched page 770, total classes so far: 38500
# 📄 Fetched page 771, total classes so far: 38550
# 📄 Fetched page 772, total classes so far: 38600
# 📄 Fetched page 773, total classes so far: 38650
# 📄 Fetched page 774, total classes so far: 38700
# 📄 Fetched page 775, total classes so far: 38750
# 📄 Fetched page 776, total classes so far: 38800
# 📄 Fetched page 777, total classes so far: 38850
# 📄 Fetched page 778, total classes so far: 38900
# 📄 Fetched page 779, total classes so far: 38950
# 📄 Fetched page 780, total classes so far: 39000
# 📄 Fetched page 781, total classes so far: 39050
# 📄 Fetched page 782, total classes so far: 39100
# 📄 Fetched page 783, total classes so far: 39150
# 📄 Fetched page 784, total classes so far: 39200
# 📄 Fetched page 785, total classes so far: 39250
# 📄 Fetched page 786, total classes so far: 39300
# 📄 Fetched page 787, total classes so far: 39350
# 📄 Fetched page 788, total classes so far: 39400
# 📄 Fetched page 789, total classes so far: 39450
# 📄 Fetched page 790, total classes so far: 39500
# 📄 Fetched page 791, total classes so far: 39550
# 📄 Fetched page 792, total classes so far: 39600
# 📄 Fetched page 793, total classes so far: 39650
# 📄 Fetched page 794, total classes so far: 39700
# 📄 Fetched page 795, total classes so far: 39750
# 📄 Fetched page 796, total classes so far: 39800
# 📄 Fetched page 797, total classes so far: 39850
# 📄 Fetched page 798, total classes so far: 39900
# 📄 Fetched page 799, total classes so far: 39950
# 📄 Fetched page 800, total classes so far: 40000
# 📄 Fetched page 801, total classes so far: 40050
# 📄 Fetched page 802, total classes so far: 40100
# 📄 Fetched page 803, total classes so far: 40150
# 📄 Fetched page 804, total classes so far: 40200
# 📄 Fetched page 805, total classes so far: 40250
# 📄 Fetched page 806, total classes so far: 40300
# 📄 Fetched page 807, total classes so far: 40350
# 📄 Fetched page 808, total classes so far: 40400
# 📄 Fetched page 809, total classes so far: 40450
# 📄 Fetched page 810, total classes so far: 40500
# 📄 Fetched page 811, total classes so far: 40550
# 📄 Fetched page 812, total classes so far: 40600
# 📄 Fetched page 813, total classes so far: 40650
# 📄 Fetched page 814, total classes so far: 40700
# 📄 Fetched page 815, total classes so far: 40750
# 📄 Fetched page 816, total classes so far: 40800
# 📄 Fetched page 817, total classes so far: 40850
# 📄 Fetched page 818, total classes so far: 40900
# 📄 Fetched page 819, total classes so far: 40950
# 📄 Fetched page 820, total classes so far: 41000
# 📄 Fetched page 821, total classes so far: 41050
# 📄 Fetched page 822, total classes so far: 41100
# 📄 Fetched page 823, total classes so far: 41150
# 📄 Fetched page 824, total classes so far: 41200
# 📄 Fetched page 825, total classes so far: 41250
# 📄 Fetched page 826, total classes so far: 41300
# 📄 Fetched page 827, total classes so far: 41350
# 📄 Fetched page 828, total classes so far: 41400
# 📄 Fetched page 829, total classes so far: 41450
# 📄 Fetched page 830, total classes so far: 41500
# 📄 Fetched page 831, total classes so far: 41550
# 📄 Fetched page 832, total classes so far: 41600
# 📄 Fetched page 833, total classes so far: 41650
# 📄 Fetched page 834, total classes so far: 41700
# 📄 Fetched page 835, total classes so far: 41750
# 📄 Fetched page 836, total classes so far: 41800
# 📄 Fetched page 837, total classes so far: 41850
# 📄 Fetched page 838, total classes so far: 41900
# 📄 Fetched page 839, total classes so far: 41950
# 📄 Fetched page 840, total classes so far: 42000
# 📄 Fetched page 841, total classes so far: 42050
# 📄 Fetched page 842, total classes so far: 42100
# 📄 Fetched page 843, total classes so far: 42150
# 📄 Fetched page 844, total classes so far: 42200
# 📄 Fetched page 845, total classes so far: 42250
# 📄 Fetched page 846, total classes so far: 42300
# 📄 Fetched page 847, total classes so far: 42350
# 📄 Fetched page 848, total classes so far: 42400
# 📄 Fetched page 849, total classes so far: 42450
# 📄 Fetched page 850, total classes so far: 42500
# 📄 Fetched page 851, total classes so far: 42550
# 📄 Fetched page 852, total classes so far: 42600
# 📄 Fetched page 853, total classes so far: 42650
# 📄 Fetched page 854, total classes so far: 42700
# 📄 Fetched page 855, total classes so far: 42750
# 📄 Fetched page 856, total classes so far: 42800
# 📄 Fetched page 857, total classes so far: 42850
# 📄 Fetched page 858, total classes so far: 42900
# 📄 Fetched page 859, total classes so far: 42950
# 📄 Fetched page 860, total classes so far: 43000
# 📄 Fetched page 861, total classes so far: 43050
# 📄 Fetched page 862, total classes so far: 43100
# 📄 Fetched page 863, total classes so far: 43150
# 📄 Fetched page 864, total classes so far: 43200
# 📄 Fetched page 865, total classes so far: 43250
# 📄 Fetched page 866, total classes so far: 43300
# 📄 Fetched page 867, total classes so far: 43350
# 📄 Fetched page 868, total classes so far: 43400
# 📄 Fetched page 869, total classes so far: 43450
# 📄 Fetched page 870, total classes so far: 43500
# 📄 Fetched page 871, total classes so far: 43550
# 📄 Fetched page 872, total classes so far: 43600
# 📄 Fetched page 873, total classes so far: 43650
# 📄 Fetched page 874, total classes so far: 43700
# 📄 Fetched page 875, total classes so far: 43750
# 📄 Fetched page 876, total classes so far: 43800
# 📄 Fetched page 877, total classes so far: 43850
# 📄 Fetched page 878, total classes so far: 43900
# 📄 Fetched page 879, total classes so far: 43950
# 📄 Fetched page 880, total classes so far: 44000
# 📄 Fetched page 881, total classes so far: 44050
# 📄 Fetched page 882, total classes so far: 44100
# 📄 Fetched page 883, total classes so far: 44150
# 📄 Fetched page 884, total classes so far: 44200
# 📄 Fetched page 885, total classes so far: 44250
# 📄 Fetched page 886, total classes so far: 44300
# 📄 Fetched page 887, total classes so far: 44350
# 📄 Fetched page 888, total classes so far: 44400
# 📄 Fetched page 889, total classes so far: 44450
# 📄 Fetched page 890, total classes so far: 44500
# 📄 Fetched page 891, total classes so far: 44550
# 📄 Fetched page 892, total classes so far: 44600
# 📄 Fetched page 893, total classes so far: 44650
# 📄 Fetched page 894, total classes so far: 44700
# 📄 Fetched page 895, total classes so far: 44750
# 📄 Fetched page 896, total classes so far: 44800
# 📄 Fetched page 897, total classes so far: 44850
# 📄 Fetched page 898, total classes so far: 44900
# 📄 Fetched page 899, total classes so far: 44950
# 📄 Fetched page 900, total classes so far: 45000
# 📄 Fetched page 901, total classes so far: 45050
# 📄 Fetched page 902, total classes so far: 45100
# 📄 Fetched page 903, total classes so far: 45150
# 📄 Fetched page 904, total classes so far: 45200
# 📄 Fetched page 905, total classes so far: 45250
# 📄 Fetched page 906, total classes so far: 45300
# 📄 Fetched page 907, total classes so far: 45350
# 📄 Fetched page 908, total classes so far: 45400
# 📄 Fetched page 909, total classes so far: 45450
# 📄 Fetched page 910, total classes so far: 45500
# 📄 Fetched page 911, total classes so far: 45550
# 📄 Fetched page 912, total classes so far: 45600
# 📄 Fetched page 913, total classes so far: 45650
# 📄 Fetched page 914, total classes so far: 45700
# 📄 Fetched page 915, total classes so far: 45750
# 📄 Fetched page 916, total classes so far: 45800
# 📄 Fetched page 917, total classes so far: 45850
# 📄 Fetched page 918, total classes so far: 45900
# 📄 Fetched page 919, total classes so far: 45950
# 📄 Fetched page 920, total classes so far: 46000
# 📄 Fetched page 921, total classes so far: 46050
# 📄 Fetched page 922, total classes so far: 46100
# 📄 Fetched page 923, total classes so far: 46150
# 📄 Fetched page 924, total classes so far: 46200
# 📄 Fetched page 925, total classes so far: 46250
# 📄 Fetched page 926, total classes so far: 46300
# 📄 Fetched page 927, total classes so far: 46350
# 📄 Fetched page 928, total classes so far: 46400
# 📄 Fetched page 929, total classes so far: 46450
# 📄 Fetched page 930, total classes so far: 46500
# 📄 Fetched page 931, total classes so far: 46550
# 📄 Fetched page 932, total classes so far: 46600
# 📄 Fetched page 933, total classes so far: 46650
# 📄 Fetched page 934, total classes so far: 46700
# 📄 Fetched page 935, total classes so far: 46750
# 📄 Fetched page 936, total classes so far: 46800
# 📄 Fetched page 937, total classes so far: 46850
# 📄 Fetched page 938, total classes so far: 46900
# 📄 Fetched page 939, total classes so far: 46950
# 📄 Fetched page 940, total classes so far: 47000
# 📄 Fetched page 941, total classes so far: 47050
# 📄 Fetched page 942, total classes so far: 47100
# 📄 Fetched page 943, total classes so far: 47150
# 📄 Fetched page 944, total classes so far: 47200
# 📄 Fetched page 945, total classes so far: 47250
# 📄 Fetched page 946, total classes so far: 47300
# 📄 Fetched page 947, total classes so far: 47350
# 📄 Fetched page 948, total classes so far: 47400
# 📄 Fetched page 949, total classes so far: 47450
# 📄 Fetched page 950, total classes so far: 47500
# 📄 Fetched page 951, total classes so far: 47550
# 📄 Fetched page 952, total classes so far: 47600
# 📄 Fetched page 953, total classes so far: 47650
# 📄 Fetched page 954, total classes so far: 47700
# 📄 Fetched page 955, total classes so far: 47750
# 📄 Fetched page 956, total classes so far: 47800
# 📄 Fetched page 957, total classes so far: 47850
# 📄 Fetched page 958, total classes so far: 47900
# 📄 Fetched page 959, total classes so far: 47950
# 📄 Fetched page 960, total classes so far: 48000
# 📄 Fetched page 961, total classes so far: 48050
# 📄 Fetched page 962, total classes so far: 48100
# 📄 Fetched page 963, total classes so far: 48150
# 📄 Fetched page 964, total classes so far: 48200
# 📄 Fetched page 965, total classes so far: 48250
# 📄 Fetched page 966, total classes so far: 48300
# 📄 Fetched page 967, total classes so far: 48350
# 📄 Fetched page 968, total classes so far: 48400
# 📄 Fetched page 969, total classes so far: 48450
# 📄 Fetched page 970, total classes so far: 48500
# 📄 Fetched page 971, total classes so far: 48550
# 📄 Fetched page 972, total classes so far: 48600
# 📄 Fetched page 973, total classes so far: 48650
# 📄 Fetched page 974, total classes so far: 48700
# 📄 Fetched page 975, total classes so far: 48750
# 📄 Fetched page 976, total classes so far: 48800
# 📄 Fetched page 977, total classes so far: 48850
# 📄 Fetched page 978, total classes so far: 48900
# 📄 Fetched page 979, total classes so far: 48950
# 📄 Fetched page 980, total classes so far: 49000
# 📄 Fetched page 981, total classes so far: 49050
# 📄 Fetched page 982, total classes so far: 49100
# 📄 Fetched page 983, total classes so far: 49150
# 📄 Fetched page 984, total classes so far: 49200
# 📄 Fetched page 985, total classes so far: 49250
# 📄 Fetched page 986, total classes so far: 49300
# 📄 Fetched page 987, total classes so far: 49350
# 📄 Fetched page 988, total classes so far: 49400
# 📄 Fetched page 989, total classes so far: 49450
# 📄 Fetched page 990, total classes so far: 49500
# 📄 Fetched page 991, total classes so far: 49550
# 📄 Fetched page 992, total classes so far: 49600
# 📄 Fetched page 993, total classes so far: 49650
# 📄 Fetched page 994, total classes so far: 49700
# 📄 Fetched page 995, total classes so far: 49750
# 📄 Fetched page 996, total classes so far: 49800
# 📄 Fetched page 997, total classes so far: 49850
# 📄 Fetched page 998, total classes so far: 49900
# 📄 Fetched page 999, total classes so far: 49950
# 📄 Fetched page 1000, total classes so far: 50000
# 📄 Fetched page 1001, total classes so far: 50050
# 📄 Fetched page 1002, total classes so far: 50100
# 📄 Fetched page 1003, total classes so far: 50150
# 📄 Fetched page 1004, total classes so far: 50200
# 📄 Fetched page 1005, total classes so far: 50250
# 📄 Fetched page 1006, total classes so far: 50300
# ...
# 📄 Fetched page 4101, total classes so far: 205050
# 📄 Fetched page 4102, total classes so far: 205100
# 📄 Fetched page 4103, total classes so far: 205150
# 📄 Fetched page 4104, total classes so far: 205200
# 📄 Fetched page 4105, total classes so far: 205250
# 📄 Fetched page 4106, total classes so far: 205300
# 📄 Fetched page 4107, total classes so far: 205350
# 📄 Fetched page 4108, total classes so far: 205400
# 📄 Fetched page 4109, total classes so far: 205450
# 📄 Fetched page 4110, total classes so far: 205500
# 📄 Fetched page 4111, total classes so far: 205550
# 📄 Fetched page 4112, total classes so far: 205600
# 📄 Fetched page 4113, total classes so far: 205650
# 📄 Fetched page 4114, total classes so far: 205700
# 📄 Fetched page 4115, total classes so far: 205750
# 📄 Fetched page 4116, total classes so far: 205800
# 📄 Fetched page 4117, total classes so far: 205850
# 📄 Fetched page 4118, total classes so far: 205900
# 📄 Fetched page 4119, total classes so far: 205950
# 📄 Fetched page 4120, total classes so far: 206000
# 📄 Fetched page 4121, total classes so far: 206050
# 📄 Fetched page 4122, total classes so far: 206100
# 📄 Fetched page 4123, total classes so far: 206150
# 📄 Fetched page 4124, total classes so far: 206200
# 📄 Fetched page 4125, total classes so far: 206250
# 📄 Fetched page 4126, total classes so far: 206300
# 📄 Fetched page 4127, total classes so far: 206350
# 📄 Fetched page 4128, total classes so far: 206400
# 📄 Fetched page 4129, total classes so far: 206450
# 📄 Fetched page 4130, total classes so far: 206500
# 📄 Fetched page 4131, total classes so far: 206550
# 📄 Fetched page 4132, total classes so far: 206600
# 📄 Fetched page 4133, total classes so far: 206650
# 📄 Fetched page 4134, total classes so far: 206700
# 📄 Fetched page 4135, total classes so far: 206750
# 📄 Fetched page 4136, total classes so far: 206800
# 📄 Fetched page 4137, total classes so far: 206850
# 📄 Fetched page 4138, total classes so far: 206900
# 📄 Fetched page 4139, total classes so far: 206950
# 📄 Fetched page 4140, total classes so far: 207000
# 📄 Fetched page 4141, total classes so far: 207050
# 📄 Fetched page 4142, total classes so far: 207100
# 📄 Fetched page 4143, total classes so far: 207150
# 📄 Fetched page 4144, total classes so far: 207200
# 📄 Fetched page 4145, total classes so far: 207250
# 📄 Fetched page 4146, total classes so far: 207300
# 📄 Fetched page 4147, total classes so far: 207350
# 📄 Fetched page 4148, total classes so far: 207400
# 📄 Fetched page 4149, total classes so far: 207450
# 📄 Fetched page 4150, total classes so far: 207500
# 📄 Fetched page 4151, total classes so far: 207550
# 📄 Fetched page 4152, total classes so far: 207600
# 📄 Fetched page 4153, total classes so far: 207650
# 📄 Fetched page 4154, total classes so far: 207700
# 📄 Fetched page 4155, total classes so far: 207750
# 📄 Fetched page 4156, total classes so far: 207800
# 📄 Fetched page 4157, total classes so far: 207850
# 📄 Fetched page 4158, total classes so far: 207900
# 📄 Fetched page 4159, total classes so far: 207950
# 📄 Fetched page 4160, total classes so far: 208000
# 📄 Fetched page 4161, total classes so far: 208050
# 📄 Fetched page 4162, total classes so far: 208100
# 📄 Fetched page 4163, total classes so far: 208150
# 📄 Fetched page 4164, total classes so far: 208200
# 📄 Fetched page 4165, total classes so far: 208250
# 📄 Fetched page 4166, total classes so far: 208300
# 📄 Fetched page 4167, total classes so far: 208350
# 📄 Fetched page 4168, total classes so far: 208400
# 📄 Fetched page 4169, total classes so far: 208450
# 📄 Fetched page 4170, total classes so far: 208500
# 📄 Fetched page 4171, total classes so far: 208550
# 📄 Fetched page 4172, total classes so far: 208600
# 📄 Fetched page 4173, total classes so far: 208650
# 📄 Fetched page 4174, total classes so far: 208700
# 📄 Fetched page 4175, total classes so far: 208750
# 📄 Fetched page 4176, total classes so far: 208800
# 📄 Fetched page 4177, total classes so far: 208850
# 📄 Fetched page 4178, total classes so far: 208900
# 📄 Fetched page 4179, total classes so far: 208950
# 📄 Fetched page 4180, total classes so far: 209000
# 📄 Fetched page 4181, total classes so far: 209050
# 📄 Fetched page 4182, total classes so far: 209100
# 📄 Fetched page 4183, total classes so far: 209150
# 📄 Fetched page 4184, total classes so far: 209200
# 📄 Fetched page 4185, total classes so far: 209250
# 📄 Fetched page 4186, total classes so far: 209300
# 📄 Fetched page 4187, total classes so far: 209350
# 📄 Fetched page 4188, total classes so far: 209400
# 📄 Fetched page 4189, total classes so far: 209450
# 📄 Fetched page 4190, total classes so far: 209500
# 📄 Fetched page 4191, total classes so far: 209550
# 📄 Fetched page 4192, total classes so far: 209600
# 📄 Fetched page 4193, total classes so far: 209650
# 📄 Fetched page 4194, total classes so far: 209700
# 📄 Fetched page 4195, total classes so far: 209750
# 📄 Fetched page 4196, total classes so far: 209800
# 📄 Fetched page 4197, total classes so far: 209850
# 📄 Fetched page 4198, total classes so far: 209900
# 📄 Fetched page 4199, total classes so far: 209950
# 📄 Fetched page 4200, total classes so far: 210000
# 📄 Fetched page 4201, total classes so far: 210050
# 📄 Fetched page 4202, total classes so far: 210100
# 📄 Fetched page 4203, total classes so far: 210150
# 📄 Fetched page 4204, total classes so far: 210200
# 📄 Fetched page 4205, total classes so far: 210250
# 📄 Fetched page 4206, total classes so far: 210300
# 📄 Fetched page 4207, total classes so far: 210350
# 📄 Fetched page 4208, total classes so far: 210400
# 📄 Fetched page 4209, total classes so far: 210450
# 📄 Fetched page 4210, total classes so far: 210500
# 📄 Fetched page 4211, total classes so far: 210550
# 📄 Fetched page 4212, total classes so far: 210600
# 📄 Fetched page 4213, total classes so far: 210650
# 📄 Fetched page 4214, total classes so far: 210700
# 📄 Fetched page 4215, total classes so far: 210750
# 📄 Fetched page 4216, total classes so far: 210800
# 📄 Fetched page 4217, total classes so far: 210850
# 📄 Fetched page 4218, total classes so far: 210900
# 📄 Fetched page 4219, total classes so far: 210950
# 📄 Fetched page 4220, total classes so far: 211000
# 📄 Fetched page 4221, total classes so far: 211050
# 📄 Fetched page 4222, total classes so far: 211100
# 📄 Fetched page 4223, total classes so far: 211150
# 📄 Fetched page 4224, total classes so far: 211200
# 📄 Fetched page 4225, total classes so far: 211250
# 📄 Fetched page 4226, total classes so far: 211300
# 📄 Fetched page 4227, total classes so far: 211350
# 📄 Fetched page 4228, total classes so far: 211400
# 📄 Fetched page 4229, total classes so far: 211450
# 📄 Fetched page 4230, total classes so far: 211500
# 📄 Fetched page 4231, total classes so far: 211550
# 📄 Fetched page 4232, total classes so far: 211600
# 📄 Fetched page 4233, total classes so far: 211650
# 📄 Fetched page 4234, total classes so far: 211700
# 📄 Fetched page 4235, total classes so far: 211750
# 📄 Fetched page 4236, total classes so far: 211800
# 📄 Fetched page 4237, total classes so far: 211850
# 📄 Fetched page 4238, total classes so far: 211900
# 📄 Fetched page 4239, total classes so far: 211950
# 📄 Fetched page 4240, total classes so far: 212000
# 📄 Fetched page 4241, total classes so far: 212050
# 📄 Fetched page 4242, total classes so far: 212100
# 📄 Fetched page 4243, total classes so far: 212150
# 📄 Fetched page 4244, total classes so far: 212200
# 📄 Fetched page 4245, total classes so far: 212250
# 📄 Fetched page 4246, total classes so far: 212300
# 📄 Fetched page 4247, total classes so far: 212350
# 📄 Fetched page 4248, total classes so far: 212400
# 📄 Fetched page 4249, total classes so far: 212450
# 📄 Fetched page 4250, total classes so far: 212500
# 📄 Fetched page 4251, total classes so far: 212550
# 📄 Fetched page 4252, total classes so far: 212600
# 📄 Fetched page 4253, total classes so far: 212650
# 📄 Fetched page 4254, total classes so far: 212700
# 📄 Fetched page 4255, total classes so far: 212750
# 📄 Fetched page 4256, total classes so far: 212800
# 📄 Fetched page 4257, total classes so far: 212850
# 📄 Fetched page 4258, total classes so far: 212900
# 📄 Fetched page 4259, total classes so far: 212950
# 📄 Fetched page 4260, total classes so far: 213000
# 📄 Fetched page 4261, total classes so far: 213050
# 📄 Fetched page 4262, total classes so far: 213100
# 📄 Fetched page 4263, total classes so far: 213150
# 📄 Fetched page 4264, total classes so far: 213200
# 📄 Fetched page 4265, total classes so far: 213250
# 📄 Fetched page 4266, total classes so far: 213300
# 📄 Fetched page 4267, total classes so far: 213350
# 📄 Fetched page 4268, total classes so far: 213400
# 📄 Fetched page 4269, total classes so far: 213450
# 📄 Fetched page 4270, total classes so far: 213500
# 📄 Fetched page 4271, total classes so far: 213550
# 📄 Fetched page 4272, total classes so far: 213600
# 📄 Fetched page 4273, total classes so far: 213650
# 📄 Fetched page 4274, total classes so far: 213700
# 📄 Fetched page 4275, total classes so far: 213750
# 📄 Fetched page 4276, total classes so far: 213800
# 📄 Fetched page 4277, total classes so far: 213850
# 📄 Fetched page 4278, total classes so far: 213900
# 📄 Fetched page 4279, total classes so far: 213950
# 📄 Fetched page 4280, total classes so far: 214000
# 📄 Fetched page 4281, total classes so far: 214050
# 📄 Fetched page 4282, total classes so far: 214100
# 📄 Fetched page 4283, total classes so far: 214150
# 📄 Fetched page 4284, total classes so far: 214200
# 📄 Fetched page 4285, total classes so far: 214250
# 📄 Fetched page 4286, total classes so far: 214300
# 📄 Fetched page 4287, total classes so far: 214350
# 📄 Fetched page 4288, total classes so far: 214400
# 📄 Fetched page 4289, total classes so far: 214450
# 📄 Fetched page 4290, total classes so far: 214500
# 📄 Fetched page 4291, total classes so far: 214550
# 📄 Fetched page 4292, total classes so far: 214600
# 📄 Fetched page 4293, total classes so far: 214650
# 📄 Fetched page 4294, total classes so far: 214700
# 📄 Fetched page 4295, total classes so far: 214750
# 📄 Fetched page 4296, total classes so far: 214800
# 📄 Fetched page 4297, total classes so far: 214850
# 📄 Fetched page 4298, total classes so far: 214900
# 📄 Fetched page 4299, total classes so far: 214950
# 📄 Fetched page 4300, total classes so far: 215000
# 📄 Fetched page 4301, total classes so far: 215050
# 📄 Fetched page 4302, total classes so far: 215100
# 📄 Fetched page 4303, total classes so far: 215150
# 📄 Fetched page 4304, total classes so far: 215200
# 📄 Fetched page 4305, total classes so far: 215250
# 📄 Fetched page 4306, total classes so far: 215300
# 📄 Fetched page 4307, total classes so far: 215350
# 📄 Fetched page 4308, total classes so far: 215400
# 📄 Fetched page 4309, total classes so far: 215450
# 📄 Fetched page 4310, total classes so far: 215500
# 📄 Fetched page 4311, total classes so far: 215550
# 📄 Fetched page 4312, total classes so far: 215600
# 📄 Fetched page 4313, total classes so far: 215650
# 📄 Fetched page 4314, total classes so far: 215700
# 📄 Fetched page 4315, total classes so far: 215750
# 📄 Fetched page 4316, total classes so far: 215800
# 📄 Fetched page 4317, total classes so far: 215850
# 📄 Fetched page 4318, total classes so far: 215900
# 📄 Fetched page 4319, total classes so far: 215950
# 📄 Fetched page 4320, total classes so far: 216000
# 📄 Fetched page 4321, total classes so far: 216050
# 📄 Fetched page 4322, total classes so far: 216100
# 📄 Fetched page 4323, total classes so far: 216150
# 📄 Fetched page 4324, total classes so far: 216200
# 📄 Fetched page 4325, total classes so far: 216250
# 📄 Fetched page 4326, total classes so far: 216300
# 📄 Fetched page 4327, total classes so far: 216350
# 📄 Fetched page 4328, total classes so far: 216400
# 📄 Fetched page 4329, total classes so far: 216450
# 📄 Fetched page 4330, total classes so far: 216500
# 📄 Fetched page 4331, total classes so far: 216550
# 📄 Fetched page 4332, total classes so far: 216600
# 📄 Fetched page 4333, total classes so far: 216650
# 📄 Fetched page 4334, total classes so far: 216700
# 📄 Fetched page 4335, total classes so far: 216750
# 📄 Fetched page 4336, total classes so far: 216800
# 📄 Fetched page 4337, total classes so far: 216850
# 📄 Fetched page 4338, total classes so far: 216900
# 📄 Fetched page 4339, total classes so far: 216950
# 📄 Fetched page 4340, total classes so far: 217000
# 📄 Fetched page 4341, total classes so far: 217050
# 📄 Fetched page 4342, total classes so far: 217100
# 📄 Fetched page 4343, total classes so far: 217150
# 📄 Fetched page 4344, total classes so far: 217200
# 📄 Fetched page 4345, total classes so far: 217250
# 📄 Fetched page 4346, total classes so far: 217300
# 📄 Fetched page 4347, total classes so far: 217350
# 📄 Fetched page 4348, total classes so far: 217400
# 📄 Fetched page 4349, total classes so far: 217450
# 📄 Fetched page 4350, total classes so far: 217500
# 📄 Fetched page 4351, total classes so far: 217550
# 📄 Fetched page 4352, total classes so far: 217600
# 📄 Fetched page 4353, total classes so far: 217650
# 📄 Fetched page 4354, total classes so far: 217700
# 📄 Fetched page 4355, total classes so far: 217750
# 📄 Fetched page 4356, total classes so far: 217800
# 📄 Fetched page 4357, total classes so far: 217850
# 📄 Fetched page 4358, total classes so far: 217900
# 📄 Fetched page 4359, total classes so far: 217950
# 📄 Fetched page 4360, total classes so far: 218000
# 📄 Fetched page 4361, total classes so far: 218050
# 📄 Fetched page 4362, total classes so far: 218100
# 📄 Fetched page 4363, total classes so far: 218150
# 📄 Fetched page 4364, total classes so far: 218200
# 📄 Fetched page 4365, total classes so far: 218250
# 📄 Fetched page 4366, total classes so far: 218300
# 📄 Fetched page 4367, total classes so far: 218350
# 📄 Fetched page 4368, total classes so far: 218400
# 📄 Fetched page 4369, total classes so far: 218450
# 📄 Fetched page 4370, total classes so far: 218500
# 📄 Fetched page 4371, total classes so far: 218550
# 📄 Fetched page 4372, total classes so far: 218600
# 📄 Fetched page 4373, total classes so far: 218650
# 📄 Fetched page 4374, total classes so far: 218700
# 📄 Fetched page 4375, total classes so far: 218750
# 📄 Fetched page 4376, total classes so far: 218800
# 📄 Fetched page 4377, total classes so far: 218850
# 📄 Fetched page 4378, total classes so far: 218900
# 📄 Fetched page 4379, total classes so far: 218950
# 📄 Fetched page 4380, total classes so far: 219000
# 📄 Fetched page 4381, total classes so far: 219050
# 📄 Fetched page 4382, total classes so far: 219100
# 📄 Fetched page 4383, total classes so far: 219150
# 📄 Fetched page 4384, total classes so far: 219200
# 📄 Fetched page 4385, total classes so far: 219250
# 📄 Fetched page 4386, total classes so far: 219300
# 📄 Fetched page 4387, total classes so far: 219350
# 📄 Fetched page 4388, total classes so far: 219400
# 📄 Fetched page 4389, total classes so far: 219450
# 📄 Fetched page 4390, total classes so far: 219500
# 📄 Fetched page 4391, total classes so far: 219550
# 📄 Fetched page 4392, total classes so far: 219600
# 📄 Fetched page 4393, total classes so far: 219650
# 📄 Fetched page 4394, total classes so far: 219700
# 📄 Fetched page 4395, total classes so far: 219750
# 📄 Fetched page 4396, total classes so far: 219800
# 📄 Fetched page 4397, total classes so far: 219850
# 📄 Fetched page 4398, total classes so far: 219900
# 📄 Fetched page 4399, total classes so far: 219950
# 📄 Fetched page 4400, total classes so far: 220000
# 📄 Fetched page 4401, total classes so far: 220050
# 📄 Fetched page 4402, total classes so far: 220100
# 📄 Fetched page 4403, total classes so far: 220150
# 📄 Fetched page 4404, total classes so far: 220200
# 📄 Fetched page 4405, total classes so far: 220250
# 📄 Fetched page 4406, total classes so far: 220300
# 📄 Fetched page 4407, total classes so far: 220350
# 📄 Fetched page 4408, total classes so far: 220400
# 📄 Fetched page 4409, total classes so far: 220450
# 📄 Fetched page 4410, total classes so far: 220500
# 📄 Fetched page 4411, total classes so far: 220550
# 📄 Fetched page 4412, total classes so far: 220600
# 📄 Fetched page 4413, total classes so far: 220650
# 📄 Fetched page 4414, total classes so far: 220700
# 📄 Fetched page 4415, total classes so far: 220750
# 📄 Fetched page 4416, total classes so far: 220800
# 📄 Fetched page 4417, total classes so far: 220816
# ✅ No more data. Retrieval complete.
# 🎉 Retrieved 220816 classes from ChEBI!
# 💾 Classes saved to 'chebi_classes.json'
