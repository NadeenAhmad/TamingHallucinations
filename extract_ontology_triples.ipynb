# %%
# !git clone https://github.com/NadeenAhmad/NeOn-GPTAquaDivaOntology
# Out:
# Cloning into 'NeOn-GPTAquaDivaOntology'...
# remote: Enumerating objects: 422, done.
# remote: Counting objects: 100% (85/85), done.
# remote: Compressing objects: 100% (83/83), done.
# remote: Total 422 (delta 52), reused 2 (delta 2), pack-reused 337 (from 2)
# Receiving objects: 100% (422/422), 342.76 KiB | 1.88 MiB/s, done.
# Resolving deltas: 100% (225/225), done.

# %%
# !pip install rdflib
# Out:
# Collecting rdflib
#   Downloading rdflib-7.1.3-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: pyparsing<4,>=2.1.0 in /usr/local/lib/python3.11/dist-packages (from rdflib) (3.2.1)
# Downloading rdflib-7.1.3-py3-none-any.whl (564 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 564.9/564.9 kB 6.4 MB/s eta 0:00:00
# Installing collected packages: rdflib
# Successfully installed rdflib-7.1.3

# %% [markdown]
# ## Extract LLM-ontology Triples

# %%
from rdflib import Graph, RDF, RDFS, OWL, BNode
import os
import csv

def format_node(node):
    if isinstance(node, BNode):  # Skip blank nodes
        return None
    return node.split("#")[-1] if "#" in node else node.split("/")[-1]

def extract_spo_triples(ontology_url, format=None):
    g = Graph()

    # Determine format if not explicitly provided
    if format is None:
        if ontology_url.endswith(".ttl"):
            format = "turtle"
        elif ontology_url.endswith(".rdf") or ontology_url.endswith(".owl"):
            format = "application/rdf+xml"
        else:
            raise ValueError("Unsupported ontology format. Please specify 'format' explicitly.")

    g.parse(ontology_url, format=format)  # Load ontology

    spo_triples = []

    # Dictionary to store multiple domains and ranges for each predicate
    predicate_info = {}

    # Step 1: Extract domain and range information
    for s, p, o in g:
        if isinstance(s, BNode) or isinstance(o, BNode):
            continue  # Skip blank nodes
        if p == RDFS.domain:
            predicate_info.setdefault(s, {"domain": set(), "range": set()})["domain"].add(o)
        elif p == RDFS.range:
            predicate_info.setdefault(s, {"domain": set(), "range": set()})["range"].add(o)

    # Step 2: Construct SPO triples for properties with domain and range
    for predicate, info in predicate_info.items():
        for domain in info["domain"]:
            for range_ in info["range"]:
                subject = format_node(domain)
                pred = format_node(predicate)
                obj = format_node(range_)
                if subject and obj:  # Ensure blank nodes are skipped
                    spo_triples.append((subject, pred, obj))

    # Step 3: Extract subclass relationships
    for s, p, o in g.triples((None, RDFS.subClassOf, None)):
        subject = format_node(s)
        predicate = "subClassOf"
        obj = format_node(o)
        if subject and obj:  # Ensure blank nodes are skipped
            spo_triples.append((subject, predicate, obj))

    # Step 4: Extract "is a" (rdf:type) relationships
    for s, p, o in g.triples((None, RDF.type, None)):
        subject = format_node(s)
        predicate = "is a"
        obj = format_node(o)
        if subject and obj:  # Ensure blank nodes are skipped
            spo_triples.append((subject, predicate, obj))

    return spo_triples

def save_triples_to_csv(file, triples, filename="triples.csv"):
    filename2 = "/content/drive/MyDrive/AquaDiva/LLMTriples/"+file+"_"+filename
    with open(filename2, mode="w", newline="", encoding="utf-8") as file:
        writer = csv.writer(file)
        writer.writerow(["Subject", "Predicate", "Object"])
        writer.writerows(triples)

# %%
if __name__ == "__main__":
    url = "Experiment3AquaDiva"
    ontology_url = "/content/NeOn-GPTAquaDivaOntology/Results/"+url+".ttl"  # Replace with the actual URL or file path
    triples = extract_spo_triples(ontology_url)
    save_triples_to_csv(url, triples)

    print("\nExtracted Subject-Predicate-Object Triples:")
    for subject, predicate, obj in triples:
        print(f"({subject}) -[{predicate}]-> ({obj})")
    print("\nExtracted Subject-Predicate-Object Triples saved to triples.csv")
# Out:
# Extracted Subject-Predicate-Object Triples:
# (PhysiochemicalParameters) -[hasOxygenContent]-> (float)
# (EukaryoticOrganism) -[isBehaviorAffectedBy]-> (CarbonateDissortation)
# (MicrobialCommunity) -[comparedTo]-> (AbovegroundEnvironment)
# (Mineral) -[hasMineralDensity]-> (float)
# (TraceGas) -[hasTraceGasConcentration]-> (float)
# (SamplingMethod) -[hasSampleID]-> (string)
# (RechargeRate) -[hasRechargeRateValue]-> (float)
# (PhysiochemicalParameters) -[changesWith]-> (AquiferSupply)
# (ChemicalComposition) -[hasChemicalConcentration]-> (float)
# (Groundwater) -[hasChemicalConcentration]-> (float)
# (SoilChemistry) -[hasSoilMoistureContent]-> (percentage)
# (MicrobialCommunityStructure) -[hasCommunityDiversityIndex]-> (float)
# (PhysiochemicalParameters) -[hasTemperature]-> (decimal)
# (PhysiochemicalParameters) -[hasTemperature]-> (float)
# (Groundwater) -[hasTemperature]-> (decimal)
# (Groundwater) -[hasTemperature]-> (float)
# (CarbonateDissortation) -[affectsBehaviorOf]-> (EukaryoticOrganism)
# (ManagementPractice) -[hasManagementEffectivenessScore]-> (float)
# (SoilOrganicMatter) -[hasOrganicMatterContent]-> (percentage)
# (MicrobialCommunity) -[hasCellCount]-> (integer)
# (SamplingMethod) -[hasSamplingLocation]-> (string)
# (ChemicalComposition) -[hasAquiferWith]-> (aquifer)
# (SamplingMethod) -[hasSamplingDate]-> (date)
# (PhysiochemicalParameters) -[hasConductivityValue]-> (float)
# (GroundwaterChemistry) -[hasPHLevel]-> (float)
# (WaterFlow) -[hasWaterFlowSpeed]-> (float)
# (SubsurfaceEcosystem) -[isInstructedBy]-> (Peptide)
# (PristineAquifer) -[isDominatedIn]-> (BiogeochemicalProcess)
# (aquifer) -[isPresentIn]-> (aquifer)
# (MicrobialBiosample) -[isModeledAfter]-> (GroundwaterMicroorganism)
# (MicrobialSpecies) -[hasHabitatDistribution]-> (aquifer)
# (GroundwaterPrecipitation) -[hasAnnualRainfall]-> (float)
# (NitrogenCycle) -[hasNitrogenLevel]-> (float)
# (DOCComposition) -[hasDOCConcentration]-> (float)
# (AquiferSupply) -[hasChangedBy]-> (PhysiochemicalParameters)
# (SamplingMethod) -[hasSamplingTemperature]-> (float)
# (PhysiochemicalParameters) -[hasPHValue]-> (float)
# (SamplingMethod) -[hasComparison]-> (EnvironmentalStudy)
# (MicrobialCommunity) -[hasMicrobialCommunityID]-> (string)
# (aquifer) -[hasDominantFunctionalGuild]-> (MicrobialFunctionalGuild)
# (Precipitation) -[hasPrecipitationDate]-> (date)
# (SamplingMethod) -[hasSamplingDepth]-> (float)
# (GroundwaterVelocity) -[hasGroundwaterVelocityValue]-> (float)
# (RareSpeciesBiodiversity) -[hasSpeciesCount]-> (positiveInteger)
# (GeochemicalProcess) -[hasCarbonIsotopeRatio]-> (float)
# (GeochemicalProcess) -[hasDenitrificationRate]-> (float)
# (PhysiochemicalParameters) -[hasConductivity]-> (float)
# (AquiferSystem) -[hasAquiferDepth]-> (float)
# (aquifer) -[inAquiferWith]-> (ChemicalComposition)
# (AbovegroundEnvironment) -[isComparedTo]-> (MicrobialCommunity)
# (Microbes) -[hasMicrobialDensity]-> (positiveInteger)
# (InfiltrationArea) -[hasInfiltrationRate]-> (float)
# (aquifer) -[isHabitatDistributionFor]-> (MicrobialSpecies)
# (aquifer) -[hasAquiferID]-> (string)
# (GroundwaterEcosystem) -[hasCO2EmissionRate]-> (float)
# (Permeability) -[hasPermeabilityIndex]-> (float)
# (GroundwaterContamination) -[hasGroundwaterContaminationLevel]-> (float)
# (PhysiochemicalParameters) -[hasDOValue]-> (float)
# (RockType) -[hasRockPorosity]-> (decimal)
# (MicrobialFunctionalGuild) -[isDominantFunctionalGuildOf]-> (aquifer)
# (Vegetation) -[hasVegetationDensity]-> (positiveInteger)
# (Precipitation) -[hasPrecipitationValue]-> (float)
# (MicrobialCommunity) -[hasNitrogenContent]-> (float)
# (GroundwaterContamination) -[hasPollutionLevel]-> (float)
# (Biodiversity) -[hasBiodiversityIndex]-> (float)
# (MicrobialDiversity) -[hasBiodiversityIndex]-> (float)
# (GroundwaterProtection) -[isUsedFor]-> (SamplingMethod)
# (AbioticFactor) -[subClassOf]-> (EcologicalFactor)
# (BioticFactor) -[subClassOf]-> (EcologicalFactor)
# (AgriculturalActivity) -[subClassOf]-> (LandUseActivity)
# (AgriculturalPractice) -[subClassOf]-> (LandUseActivity)
# (AmazonRainforestSoil) -[subClassOf]-> (Soil)
# (AnalysisMethod) -[subClassOf]-> (Method)
# (SamplingMethod) -[subClassOf]-> (Method)
# (AquaticFungi) -[subClassOf]-> (Fungi)
# (AquiferFungiSample) -[subClassOf]-> (Fungi)
# (AquaticMicrobialCommunity) -[subClassOf]-> (Community)
# (MicrobialCommunity) -[subClassOf]-> (Community)
# (AquiferChemistry) -[subClassOf]-> (Geochemistry)
# (GroundwaterChemistry) -[subClassOf]-> (Geochemistry)
# (Hydrochemistry) -[subClassOf]-> (Geochemistry)
# (SoilChemistry) -[subClassOf]-> (Geochemistry)
# (AquiferSystem) -[subClassOf]-> (HydrogeologicalSystem)
# (Biodiversity) -[subClassOf]-> (EcologicalMetric)
# (Bioturbation) -[subClassOf]-> (EcologicalProcess)
# (Consumption) -[subClassOf]-> (EcologicalProcess)
# (MicrobialDynamics) -[subClassOf]-> (EcologicalProcess)
# (Production) -[subClassOf]-> (EcologicalProcess)
# (CO2FixationPathway) -[subClassOf]-> (BiochemicalPathway)
# (CO2ReductionPathway) -[subClassOf]-> (BiochemicalPathway)
# (EnergyMetabolismPathway) -[subClassOf]-> (BiochemicalPathway)
# (CarbonateDissolution) -[subClassOf]-> (ChemicalProcess)
# (CarbonateDissortation) -[subClassOf]-> (ChemicalProcess)
# (CatchmentArea) -[subClassOf]-> (HydrologicalUnit)
# (InfiltrationArea) -[subClassOf]-> (HydrologicalUnit)
# (RechargeZone) -[subClassOf]-> (HydrologicalUnit)
# (ChalkAquifer) -[subClassOf]-> (AquiferSystem)
# (DeepAquifer) -[subClassOf]-> (AquiferSystem)
# (KarstAquifer) -[subClassOf]-> (AquiferSystem)
# (KarstAquiferSystem) -[subClassOf]-> (AquiferSystem)
# (LimestoneAquifer) -[subClassOf]-> (AquiferSystem)
# (MultilevelGroundwaterSystem) -[subClassOf]-> (AquiferSystem)
# (TriassicAquifer) -[subClassOf]-> (AquiferSystem)
# (ChemicalCompound) -[subClassOf]-> (GroundwaterChemical)
# (ContaminatedSite) -[subClassOf]-> (Site)
# (DOM) -[subClassOf]-> (OrganicMatter)
# (MobileOrganicMatter) -[subClassOf]-> (OrganicMatter)
# (SoilOrganicMatter) -[subClassOf]-> (OrganicMatter)
# (DesertSpring) -[subClassOf]-> (WaterSource)
# (EnvironmentalSignal) -[subClassOf]-> (Signal)
# (ForestEcosystem) -[subClassOf]-> (Ecosystem)
# (GroundwaterEcosystem) -[subClassOf]-> (Ecosystem)
# (ForestMicrohabitat) -[subClassOf]-> (Microhabitat)
# (FracturedRock) -[subClassOf]-> (GeologicalStrata)
# (KarstSystem) -[subClassOf]-> (GeologicalStrata)
# (FracturedRockAquifer) -[subClassOf]-> (Aquifer)
# (FracturedRockAquifer) -[subClassOf]-> (aquifer)
# (KarstAquifer) -[subClassOf]-> (aquifer)
# (LowerAquifer) -[subClassOf]-> (aquifer)
# (TriassicLimestoneAquifer) -[subClassOf]-> (aquifer)
# (UpperAquifer) -[subClassOf]-> (aquifer)
# (PristineAquifer) -[subClassOf]-> (aquifer)
# (Fungi) -[subClassOf]-> (Microorganism)
# (Geochemistry) -[subClassOf]-> (EarthScience)
# (GeologicalStrata) -[subClassOf]-> (Strata)
# (Groundwater) -[subClassOf]-> (Water)
# (KarstSpringWater) -[subClassOf]-> (Water)
# (GroundwaterComparison) -[subClassOf]-> (GroundwaterStudy)
# (GroundwaterContamination) -[subClassOf]-> (Contamination)
# (GroundwaterFlow) -[subClassOf]-> (HydrologicalProcess)
# (WaterFlow) -[subClassOf]-> (HydrologicalProcess)
# (WaterInput) -[subClassOf]-> (HydrologicalProcess)
# (GroundwaterPhysiochemicalParameters) -[subClassOf]-> (PhysiochemicalParameters)
# (GroundwaterPrecipitation) -[subClassOf]-> (Precipitation)
# (GroundwaterProtection) -[subClassOf]-> (EnvironmentalProtection)
# (GroundwaterQuality) -[subClassOf]-> (Groundwater)
# (HighCalciumWater) -[subClassOf]-> (Groundwater)
# (GroundwaterVulnerability) -[subClassOf]-> (EnvironmentalVulnerability)
# (HainichCZObservatory) -[subClassOf]-> (Observatory)
# (HainichCriticalZone) -[subClassOf]-> (CriticalZone)
# (HydraulicConductivityStudy) -[subClassOf]-> (HydrologicalStudy)
# (SoilTracerStudy) -[subClassOf]-> (HydrologicalStudy)
# (HydraulicProperty) -[subClassOf]-> (Property)
# (HydrologicalProperty) -[subClassOf]-> (Property)
# (HydrogeochemicalCharacterizationMethod) -[subClassOf]-> (CharacterizationMethod)
# (IndustrialAgricultureArea) -[subClassOf]-> (AgriculturalArea)
# (Karst) -[subClassOf]-> (GeologicalFormation)
# (MuschelkalkFormation) -[subClassOf]-> (GeologicalFormation)
# (Karstification) -[subClassOf]-> (GeologicalProcess)
# (Limestone) -[subClassOf]-> (RockType)
# (ManagementPractice) -[subClassOf]-> (LandManagement)
# (MarinePhage) -[subClassOf]-> (Phage)
# (Microbes) -[subClassOf]-> (AquaticMicrobes)
# (Microbes) -[subClassOf]-> (GroundwaterMicrobes)
# (MicrobialFunctionalGuilds) -[subClassOf]-> (MicrobialCommunity)
# (MicrobialMechanism) -[subClassOf]-> (EcologicalMechanism)
# (Mineral) -[subClassOf]-> (GeologicalMaterial)
# (RockType) -[subClassOf]-> (GeologicalMaterial)
# (Miz) -[subClassOf]-> (Biomarker)
# (MolecularMarker) -[subClassOf]-> (Biomarker)
# (MolecularFormula) -[subClassOf]-> (ChemicalData)
# (NitrogenCycle) -[subClassOf]-> (BiogeochemicalCycle)
# (NitrogenTransformation) -[subClassOf]-> (BiogeochemicalProcess)
# (OrganicGroundwaterComponent) -[subClassOf]-> (OrganicComponent)
# (Permeability) -[subClassOf]-> (HydrogeologicalProperty)
# (PhosphateMinerals) -[subClassOf]-> (Minerals)
# (SecondaryMinerals) -[subClassOf]-> (Minerals)
# (RareSpeciesBiodiversity) -[subClassOf]-> (Biodiversity)
# (SeasonalVariation) -[subClassOf]-> (EnvironmentalVariation)
# (SeasonalWetland) -[subClassOf]-> (Wetland)
# (SoilGroundwaterInteraction) -[subClassOf]-> (EcologicalInteraction)
# (SoilWaterContent) -[subClassOf]-> (SoilProperty)
# (SpatialPattern) -[subClassOf]-> (Pattern)
# (TemporalPattern) -[subClassOf]-> (Pattern)
# (SubsurfaceBacterialCulture) -[subClassOf]-> (MicrobialCulture)
# (Terrain) -[subClassOf]-> (GeologicalFeature)
# (TraceGas) -[subClassOf]-> (Gas)
# (TriassicLimestone) -[subClassOf]-> (Limestone)
# (Vegetation) -[subClassOf]-> (PlantCommunity)
# (VegetationCover) -[subClassOf]-> (PlantCover)
# (VegetationType) -[subClassOf]-> (PlantType)
# (AbioticFactor) -[is a]-> (Class)
# (AgriculturalActivity) -[is a]-> (Class)
# (AgriculturalPractice) -[is a]-> (Class)
# (AmazonRainforestSoil) -[is a]-> (Class)
# (AnalysisMethod) -[is a]-> (Class)
# (AquaticFungi) -[is a]-> (Class)
# (AquaticMicrobes) -[is a]-> (Class)
# (AquaticMicrobialCommunity) -[is a]-> (Class)
# (AquiferChemistry) -[is a]-> (Class)
# (AquiferFungiSample) -[is a]-> (Class)
# (AquiferSystem) -[is a]-> (Class)
# (Biodiversity) -[is a]-> (Class)
# (BioticFactor) -[is a]-> (Class)
# (Bioturbation) -[is a]-> (Class)
# (CO2FixationPathway) -[is a]-> (Class)
# (CO2ReductionPathway) -[is a]-> (Class)
# (CarbonateDissolution) -[is a]-> (Class)
# (CarbonateDissortation) -[is a]-> (Class)
# (CatchmentArea) -[is a]-> (Class)
# (ChalkAquifer) -[is a]-> (Class)
# (ChemicalCompound) -[is a]-> (Class)
# (Consumption) -[is a]-> (Class)
# (ContaminatedSite) -[is a]-> (Class)
# (DOM) -[is a]-> (Class)
# (DeepAquifer) -[is a]-> (Class)
# (DesertSpring) -[is a]-> (Class)
# (EnergyMetabolismPathway) -[is a]-> (Class)
# (EnvironmentalSignal) -[is a]-> (Class)
# (ForestEcosystem) -[is a]-> (Class)
# (ForestMicrohabitat) -[is a]-> (Class)
# (FracturedRock) -[is a]-> (Class)
# (FracturedRockAquifer) -[is a]-> (Class)
# (Fungi) -[is a]-> (Class)
# (Geochemistry) -[is a]-> (Class)
# (GeologicalStrata) -[is a]-> (Class)
# (Groundwater) -[is a]-> (Class)
# (GroundwaterChemistry) -[is a]-> (Class)
# (GroundwaterComparison) -[is a]-> (Class)
# (GroundwaterContamination) -[is a]-> (Class)
# (GroundwaterEcosystem) -[is a]-> (Class)
# (GroundwaterFlow) -[is a]-> (Class)
# (GroundwaterPhysiochemicalParameters) -[is a]-> (Class)
# (GroundwaterPrecipitation) -[is a]-> (Class)
# (GroundwaterProtection) -[is a]-> (Class)
# (GroundwaterQuality) -[is a]-> (Class)
# (GroundwaterVulnerability) -[is a]-> (Class)
# (HainichCZObservatory) -[is a]-> (Class)
# (HainichCriticalZone) -[is a]-> (Class)
# (HighCalciumWater) -[is a]-> (Class)
# (HydraulicConductivityStudy) -[is a]-> (Class)
# (HydraulicProperty) -[is a]-> (Class)
# (Hydrochemistry) -[is a]-> (Class)
# (HydrogeochemicalCharacterizationMethod) -[is a]-> (Class)
# (HydrologicalProperty) -[is a]-> (Class)
# (IndustrialAgricultureArea) -[is a]-> (Class)
# (InfiltrationArea) -[is a]-> (Class)
# (Karst) -[is a]-> (Class)
# (KarstAquifer) -[is a]-> (Class)
# (KarstAquiferSystem) -[is a]-> (Class)
# (KarstSpringWater) -[is a]-> (Class)
# (KarstSystem) -[is a]-> (Class)
# (Karstification) -[is a]-> (Class)
# (Limestone) -[is a]-> (Class)
# (LimestoneAquifer) -[is a]-> (Class)
# (ManagementPractice) -[is a]-> (Class)
# (MarinePhage) -[is a]-> (Class)
# (Microbes) -[is a]-> (Class)
# (MicrobialCommunity) -[is a]-> (Class)
# (MicrobialDynamics) -[is a]-> (Class)
# (MicrobialFunctionalGuilds) -[is a]-> (Class)
# (MicrobialMechanism) -[is a]-> (Class)
# (Mineral) -[is a]-> (Class)
# (Miz) -[is a]-> (Class)
# (MobileOrganicMatter) -[is a]-> (Class)
# (MolecularFormula) -[is a]-> (Class)
# (MolecularMarker) -[is a]-> (Class)
# (MultilevelGroundwaterSystem) -[is a]-> (Class)
# (MuschelkalkFormation) -[is a]-> (Class)
# (NitrogenCycle) -[is a]-> (Class)
# (NitrogenTransformation) -[is a]-> (Class)
# (OrganicGroundwaterComponent) -[is a]-> (Class)
# (Permeability) -[is a]-> (Class)
# (PhosphateMinerals) -[is a]-> (Class)
# (Production) -[is a]-> (Class)
# (RareSpeciesBiodiversity) -[is a]-> (Class)
# (RechargeZone) -[is a]-> (Class)
# (RockType) -[is a]-> (Class)
# (SamplingMethod) -[is a]-> (Class)
# (SeasonalVariation) -[is a]-> (Class)
# (SeasonalWetland) -[is a]-> (Class)
# (SecondaryMinerals) -[is a]-> (Class)
# (SoilChemistry) -[is a]-> (Class)
# (SoilGroundwaterInteraction) -[is a]-> (Class)
# (SoilOrganicMatter) -[is a]-> (Class)
# (SoilTracerStudy) -[is a]-> (Class)
# (SoilWaterContent) -[is a]-> (Class)
# (SpatialPattern) -[is a]-> (Class)
# (SubsurfaceBacterialCulture) -[is a]-> (Class)
# (TemporalPattern) -[is a]-> (Class)
# (Terrain) -[is a]-> (Class)
# (TraceGas) -[is a]-> (Class)
# (TriassicAquifer) -[is a]-> (Class)
# (TriassicLimestone) -[is a]-> (Class)
# (Vegetation) -[is a]-> (Class)
# (VegetationCover) -[is a]-> (Class)
# (VegetationType) -[is a]-> (Class)
# (WaterFlow) -[is a]-> (Class)
# (WaterInput) -[is a]-> (Class)
# (AmazonRainforestSoil) -[is a]-> (SoilGroundwaterInteraction)
# (AquaticFungi) -[is a]-> (Class)
# (AquaticMicrobes) -[is a]-> (Class)
# (CarbonateDissortation) -[is a]-> (Class)
# (FracturedRockAquifer) -[is a]-> (Class)
# (GroundwaterContamination) -[is a]-> (Class)
# (GroundwaterQuality) -[is a]-> (Class)
# (HydraulicProperty) -[is a]-> (Class)
# (Hydrochemistry) -[is a]-> (Class)
# (KarstAquifer) -[is a]-> (Class)
# (MicrobialCommunity) -[is a]-> (Class)
# (MobileOrganicMatter) -[is a]-> (Class)
# (SamplingMethod) -[is a]-> (Class)
# (AgriculturalRunoff) -[is a]-> (Class)
# (AnoxicZone) -[is a]-> (Class)
# (AquaticColloid) -[is a]-> (Class)
# (AquiferMicrobiome) -[is a]-> (Class)
# (AquiferType) -[is a]-> (Class)
# (AquiferVulnerability) -[is a]-> (Class)
# (ChemicalSignal) -[is a]-> (Class)
# (ClimaticParameter) -[is a]-> (Class)
# (ContaminantTransportPathway) -[is a]-> (Class)
# (CrossKingdomInteraction) -[is a]-> (Class)
# (EnvironmentalContamination) -[is a]-> (Class)
# (EnvironmentalSetting) -[is a]-> (Class)
# (ExtremeWeatherEvent) -[is a]-> (Class)
# (GroundwaterBalance) -[is a]-> (Class)
# (GroundwaterInfiltrationArea) -[is a]-> (Class)
# (HydrochemicalProperties) -[is a]-> (Class)
# (LowerAquifer) -[is a]-> (Class)
# (MarineMicrobialCommunity) -[is a]-> (Class)
# (MicrobialCommunityDistribution) -[is a]-> (Class)
# (MicrobialGuild) -[is a]-> (Class)
# (MicrobialMetabolism) -[is a]-> (Class)
# (MineralOrganicInteraction) -[is a]-> (Class)
# (OxicZone) -[is a]-> (Class)
# (PedologicalSetting) -[is a]-> (Class)
# (PhysicochemicalCondition) -[is a]-> (Class)
# (PoreStructure) -[is a]-> (Class)
# (Snowmelt) -[is a]-> (Class)
# (SoilMicrobiome) -[is a]-> (Class)
# (StrataContinuity) -[is a]-> (Class)
# (SubsoilCharacteristic) -[is a]-> (Class)
# (Substrate) -[is a]-> (Class)
# (SurfaceChemicalSignal) -[is a]-> (Class)
# (Throughfall) -[is a]-> (Class)
# (TriassicLimestoneAquifer) -[is a]-> (Class)
# (UpperAquifer) -[is a]-> (Class)
# (VegetationHeterogeneity) -[is a]-> (Class)
# (GroundwaterMicrobes) -[is a]-> (Class)
# (MicrobialCommunityStructure) -[is a]-> (Class)
# (Peptide) -[is a]-> (Class)
# (AbovegroundEnvironment) -[is a]-> (Class)
# (Biocolloid) -[is a]-> (Class)
# (BiogeochemicalCycle) -[is a]-> (Class)
# (DOCComposition) -[is a]-> (Class)
# (EukaryoticOrganism) -[is a]-> (Class)
# (GroundwaterVelocity) -[is a]-> (Class)
# (MicrobialFunctionalGuild) -[is a]-> (Class)
# (MicrobialSpecies) -[is a]-> (Class)
# (PristineAquifer) -[is a]-> (Class)
# (RechargeRate) -[is a]-> (Class)
# (SubsurfaceHabitat) -[is a]-> (Class)
# (ChemicalComposition) -[is a]-> (Class)
# (Precipitation) -[is a]-> (Class)
# (GeochemicalProcess) -[is a]-> (Class)
# (PhysiochemicalParameters) -[is a]-> (Class)
# (aquifer) -[is a]-> (Class)
# (AquaticMicrobialCommunity) -[is a]-> (MicrobialCommunity)
# (ForestMicrohabitat) -[is a]-> (MicrobialCommunity)
# (MicrobialCommunityA) -[is a]-> (MicrobialCommunity)
# (MicrobialCommunityB) -[is a]-> (MicrobialCommunity)
# (AquiferFungiSample) -[is a]-> (Fungi)
# (CO2ReductionPathway) -[is a]-> (CO2FixationPathway)
# (ChalkAquifer) -[is a]-> (LimestoneAquifer)
# (ContaminatedSite) -[is a]-> (GroundwaterContamination)
# (GroundwaterContamination1) -[is a]-> (GroundwaterContamination)
# (DeepAquifer) -[is a]-> (AquiferSystem)
# (DesertSpring) -[is a]-> (Groundwater)
# (HighCalciumWater) -[is a]-> (Groundwater)
# (KarstSpringWater) -[is a]-> (Groundwater)
# (NitrateRichWater) -[is a]-> (Groundwater)
# (FracturedRockAquifer) -[is a]-> (GroundwaterQuality)
# (HainichCZObservatory) -[is a]-> (HainichCriticalZone)
# (HydraulicConductivityStudy) -[is a]-> (HydrogeochemicalCharacterizationMethod)
# (IndustrialAgricultureArea) -[is a]-> (AgriculturalActivity)
# (KarstAquiferSystem) -[is a]-> (KarstAquifer)
# (KarstAquifer2) -[is a]-> (KarstAquifer)
# (PhosphateMinerals) -[is a]-> (Mineral)
# (RechargeZone) -[is a]-> (InfiltrationArea)
# (SeasonalWetland) -[is a]-> (GroundwaterPrecipitation)
# (SubsurfaceBacterialCulture) -[is a]-> (Microbes)
# (TriassicLimestone) -[is a]-> (GeologicalFormation)
# (aquadiva) -[is a]-> (Ontology)
# (DOCCompositionSample1) -[is a]-> (DOCComposition)
# (FracturedRockAquifer1) -[is a]-> (FracturedRockAquifer)
# (GeochemicalProcess1) -[is a]-> (GeochemicalProcess)
# (GroundwaterSample1) -[is a]-> (SamplingMethod)
# (GroundwaterVelocitySample1) -[is a]-> (GroundwaterVelocity)
# (HainichAquifer) -[is a]-> (aquifer)
# (MicrobialDiversitySample1) -[is a]-> (MicrobialDiversity)
# (PrecipitationEvent1) -[is a]-> (Precipitation)
# (RechargeRateSample1) -[is a]-> (RechargeRate)
# (adaptsTo) -[is a]-> (Property)
# (existsIn) -[is a]-> (Property)
# (hasComponents) -[is a]-> (Property)
# (hasRoleIn) -[is a]-> (Property)
# (isAffected) -[is a]-> (Property)
# (isAffectedBy) -[is a]-> (Property)
# (isAssociatedWith) -[is a]-> (Property)
# (isCharacterizedBy) -[is a]-> (Property)
# (isDefinedBy) -[is a]-> (Property)
# (isDetectedThrough) -[is a]-> (Property)
# (isFoundIn) -[is a]-> (Property)
# (isIndicatedBy) -[is a]-> (Property)
# (isInfluenced) -[is a]-> (Property)
# (isInfluencedBy) -[is a]-> (Property)
# (isInvolvedIn) -[is a]-> (Property)
# (isPhaseOf) -[is a]-> (Property)
# (isRelatedTo) -[is a]-> (Property)
# (isUsedFor) -[is a]-> (Property)
# (isUsedIn) -[is a]-> (Property)
# (occursIn) -[is a]-> (Property)
# (adaptTo) -[is a]-> (Property)
# (affect) -[is a]-> (Property)
# (affectedBy) -[is a]-> (Property)
# (define) -[is a]-> (Property)
# (detectedThrough) -[is a]-> (Property)
# (existIn) -[is a]-> (Property)
# (hasCharacteristic) -[is a]-> (Property)
# (hasComponent) -[is a]-> (Property)
# (hasPhase) -[is a]-> (Property)
# (impact) -[is a]-> (Property)
# (impacts) -[is a]-> (Property)
# (indicate) -[is a]-> (Property)
# (influence) -[is a]-> (Property)
# (influencedBy) -[is a]-> (Property)
# (interactWith) -[is a]-> (Property)
# (interactsWith) -[is a]-> (Property)
# (involvedIn) -[is a]-> (Property)
# (occurIn) -[is a]-> (Property)
# (playRoleIn) -[is a]-> (Property)
# (relatedTo) -[is a]-> (Property)
# (usedFor) -[is a]-> (Property)
# (usedIn) -[is a]-> (Property)
# (associatedWith) -[is a]-> (Property)
# (foundIn) -[is a]-> (Property)
# (existsIn) -[is a]-> (FunctionalProperty)
# (hasAquiferWith) -[is a]-> (FunctionalProperty)
# (hasRole) -[is a]-> (FunctionalProperty)
# (isComparedTo) -[is a]-> (FunctionalProperty)
# (isContributedBy) -[is a]-> (FunctionalProperty)
# (isImpactedBy) -[is a]-> (FunctionalProperty)
# (isModeledAfter) -[is a]-> (FunctionalProperty)
# (isPresentIn) -[is a]-> (FunctionalProperty)
# (isUsedFor) -[is a]-> (FunctionalProperty)
# (affects) -[is a]-> (FunctionalProperty)
# (define) -[is a]-> (FunctionalProperty)
# (dominatesIn) -[is a]-> (FunctionalProperty)
# (hasCharacteristic) -[is a]-> (FunctionalProperty)
# (hasComponent) -[is a]-> (FunctionalProperty)
# (hasDominantFunctionalGuild) -[is a]-> (FunctionalProperty)
# (hasHabitatDistribution) -[is a]-> (FunctionalProperty)
# (hasPhase) -[is a]-> (FunctionalProperty)
# (inAquiferWith) -[is a]-> (FunctionalProperty)
# (influences) -[is a]-> (FunctionalProperty)
# (maintains) -[is a]-> (FunctionalProperty)
# (playsRoleIn) -[is a]-> (FunctionalProperty)
# (usedIn) -[is a]-> (FunctionalProperty)
# (associatedWith) -[is a]-> (FunctionalProperty)
# (hasAnnualRainfall) -[is a]-> (DatatypeProperty)
# (hasAquiferDepth) -[is a]-> (DatatypeProperty)
# (hasAquiferID) -[is a]-> (DatatypeProperty)
# (hasBiodiversityIndex) -[is a]-> (DatatypeProperty)
# (hasCO2EmissionRate) -[is a]-> (DatatypeProperty)
# (hasCarbonIsotopeRatio) -[is a]-> (DatatypeProperty)
# (hasCellCount) -[is a]-> (DatatypeProperty)
# (hasChemicalConcentration) -[is a]-> (DatatypeProperty)
# (hasCommunityDiversityIndex) -[is a]-> (DatatypeProperty)
# (hasConductivity) -[is a]-> (DatatypeProperty)
# (hasConductivityValue) -[is a]-> (DatatypeProperty)
# (hasDOCConcentration) -[is a]-> (DatatypeProperty)
# (hasDOValue) -[is a]-> (DatatypeProperty)
# (hasDenitrificationRate) -[is a]-> (DatatypeProperty)
# (hasGroundwaterContaminationLevel) -[is a]-> (DatatypeProperty)
# (hasGroundwaterVelocityValue) -[is a]-> (DatatypeProperty)
# (hasInfiltrationRate) -[is a]-> (DatatypeProperty)
# (hasManagementEffectivenessScore) -[is a]-> (DatatypeProperty)
# (hasMicrobialCommunityID) -[is a]-> (DatatypeProperty)
# (hasMicrobialDensity) -[is a]-> (DatatypeProperty)
# (hasMineralDensity) -[is a]-> (DatatypeProperty)
# (hasNitrogenContent) -[is a]-> (DatatypeProperty)
# (hasNitrogenLevel) -[is a]-> (DatatypeProperty)
# (hasOrganicMatterContent) -[is a]-> (DatatypeProperty)
# (hasOxygenContent) -[is a]-> (DatatypeProperty)
# (hasPHLevel) -[is a]-> (DatatypeProperty)
# (hasPHValue) -[is a]-> (DatatypeProperty)
# (hasPermeabilityIndex) -[is a]-> (DatatypeProperty)
# (hasPollutionLevel) -[is a]-> (DatatypeProperty)
# (hasPrecipitationDate) -[is a]-> (DatatypeProperty)
# (hasPrecipitationValue) -[is a]-> (DatatypeProperty)
# (hasRechargeRateValue) -[is a]-> (DatatypeProperty)
# (hasRockPorosity) -[is a]-> (DatatypeProperty)
# (hasSampleID) -[is a]-> (DatatypeProperty)
# (hasSamplingDate) -[is a]-> (DatatypeProperty)
# (hasSamplingDepth) -[is a]-> (DatatypeProperty)
# (hasSamplingLocation) -[is a]-> (DatatypeProperty)
# (hasSamplingTemperature) -[is a]-> (DatatypeProperty)
# (hasSoilMoistureContent) -[is a]-> (DatatypeProperty)
# (hasSpeciesCount) -[is a]-> (DatatypeProperty)
# (hasTemperature) -[is a]-> (DatatypeProperty)
# (hasTraceGasConcentration) -[is a]-> (DatatypeProperty)
# (hasVegetationDensity) -[is a]-> (DatatypeProperty)
# (hasWaterFlowSpeed) -[is a]-> (DatatypeProperty)
# (hasAquiferWith) -[is a]-> (ObjectProperty)
# (hasChangedBy) -[is a]-> (ObjectProperty)
# (hasComparison) -[is a]-> (ObjectProperty)
# (hasInteractionWith) -[is a]-> (ObjectProperty)
# (hasRole) -[is a]-> (ObjectProperty)
# (isAffectedBy) -[is a]-> (ObjectProperty)
# (isBehaviorAffectedBy) -[is a]-> (ObjectProperty)
# (isComparedTo) -[is a]-> (ObjectProperty)
# (isContributedBy) -[is a]-> (ObjectProperty)
# (isDominantFunctionalGuildOf) -[is a]-> (ObjectProperty)
# (isDominatedIn) -[is a]-> (ObjectProperty)
# (isFoundIn) -[is a]-> (ObjectProperty)
# (isHabitatDistributionFor) -[is a]-> (ObjectProperty)
# (isImpactedBy) -[is a]-> (ObjectProperty)
# (isInfluencedBy) -[is a]-> (ObjectProperty)
# (isInstructedBy) -[is a]-> (ObjectProperty)
# (isModeledAfter) -[is a]-> (ObjectProperty)
# (isPartOf) -[is a]-> (ObjectProperty)
# (isPresentIn) -[is a]-> (ObjectProperty)
# (isRoleOf) -[is a]-> (ObjectProperty)
# (isSimilarTo) -[is a]-> (ObjectProperty)
# (isUsedFor) -[is a]-> (ObjectProperty)
# (variedBy) -[is a]-> (ObjectProperty)
# (affects) -[is a]-> (ObjectProperty)
# (affectsBehaviorOf) -[is a]-> (ObjectProperty)
# (changesWith) -[is a]-> (ObjectProperty)
# (contributeTo) -[is a]-> (ObjectProperty)
# (dominatesIn) -[is a]-> (ObjectProperty)
# (hasDominantFunctionalGuild) -[is a]-> (ObjectProperty)
# (hasHabitatDistribution) -[is a]-> (ObjectProperty)
# (hasPart) -[is a]-> (ObjectProperty)
# (inAquiferWith) -[is a]-> (ObjectProperty)
# (influences) -[is a]-> (ObjectProperty)
# (interactsWith) -[is a]-> (ObjectProperty)
# (maintains) -[is a]-> (ObjectProperty)
# (playsRoleIn) -[is a]-> (ObjectProperty)
# (presentIn) -[is a]-> (ObjectProperty)
# (variesBetween) -[is a]-> (ObjectProperty)
# (associatedWith) -[is a]-> (ObjectProperty)
# (comparedTo) -[is a]-> (ObjectProperty)
# (foundIn) -[is a]-> (ObjectProperty)
# (hasInteractionWith) -[is a]-> (SymmetricProperty)
# (isAssociatedWith) -[is a]-> (SymmetricProperty)
# (isComparedTo) -[is a]-> (SymmetricProperty)
# (isInfluencedBy) -[is a]-> (SymmetricProperty)
# (isModeledAfter) -[is a]-> (SymmetricProperty)
# (isPartOf) -[is a]-> (SymmetricProperty)
# (isRelatedTo) -[is a]-> (SymmetricProperty)
# (isSimilarTo) -[is a]-> (SymmetricProperty)
# (interactWith) -[is a]-> (SymmetricProperty)
# (interactsWith) -[is a]-> (SymmetricProperty)
# (associatedWith) -[is a]-> (SymmetricProperty)
# (hasRole) -[is a]-> (ReflexiveProperty)
# (isImpactedBy) -[is a]-> (ReflexiveProperty)
# (isInfluencedBy) -[is a]-> (ReflexiveProperty)
# (isModeledAfter) -[is a]-> (ReflexiveProperty)
# (isPartOf) -[is a]-> (ReflexiveProperty)
# (isRelatedTo) -[is a]-> (ReflexiveProperty)
# (isSimilarTo) -[is a]-> (ReflexiveProperty)
# (affects) -[is a]-> (ReflexiveProperty)
# (dominatesIn) -[is a]-> (ReflexiveProperty)
# (hasPart) -[is a]-> (ReflexiveProperty)
# (interactsWith) -[is a]-> (ReflexiveProperty)
# (maintains) -[is a]-> (ReflexiveProperty)
# (associatedWith) -[is a]-> (ReflexiveProperty)
# (isAffectedBy) -[is a]-> (TransitiveProperty)
# (isAssociatedWith) -[is a]-> (TransitiveProperty)
# (isImpactedBy) -[is a]-> (TransitiveProperty)
# (isModeledAfter) -[is a]-> (TransitiveProperty)
# (isPartOf) -[is a]-> (TransitiveProperty)
# (occursIn) -[is a]-> (TransitiveProperty)
# (affects) -[is a]-> (TransitiveProperty)
# (dominatesIn) -[is a]-> (TransitiveProperty)
# (hasPart) -[is a]-> (TransitiveProperty)
# (influences) -[is a]-> (TransitiveProperty)
# (associatedWith) -[is a]-> (TransitiveProperty)
#
# Extracted Subject-Predicate-Object Triples saved to triples.csv

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Extract BioPortal Triples

# %%
import rdflib
import csv

# Load the ontology from BioPortal
ontology_name = "OBOE-SBC"  # Extracted ontology name
csv_filename = f"{ontology_name}.csv"  # Filename based on ontology

ontology_url = "https://data.bioontology.org/ontologies/OBOE-SBC/submissions/1/download?apikey=87918894-263d-4f71-9b22-bfc345c1800d"

# Initialize RDF Graph
g = rdflib.Graph()
g.parse(ontology_url, format="application/rdf+xml")

# Extract all properties dynamically by finding all predicates in triples
all_properties = set(g.predicates())

# Extract all triples where these properties are used
triples = []
for prop in all_properties:
    for s, _, o in g.triples((None, prop, None)):
        triples.append((s, prop, o))

# Function to extract local names from URIs
def get_local_name(uri):
    if isinstance(uri, rdflib.term.URIRef):
        return uri.split("#")[-1] if "#" in uri else uri.split("/")[-1]
    elif isinstance(uri, rdflib.term.Literal):
        return str(uri)
    return uri  # Return as-is if not a URI or Literal

# Process triples into a structured format
formatted_triples = []
for s, p, o in triples:
    formatted_triples.append([get_local_name(s), get_local_name(p), get_local_name(o)])

# Save formatted triples to a CSV file
csv_filepath = f"/content/drive/MyDrive/AquaDiva/BioPortalTriples/{csv_filename}"  # Save to a persistent path
with open(csv_filepath, mode="w", newline="", encoding="utf-8") as file:
    writer = csv.writer(file)
    writer.writerow(["Subject", "Predicate", "Object"])  # CSV header
    writer.writerows(formatted_triples)

print(f"\n✅ Data saved to {csv_filename} successfully!")
# Out:
# ✅ Data saved to OBOE-SBC.csv successfully!

# %%
import rdflib
import csv

# Define ontology details
ontology_name = "ENVO"  # Ontology name
csv_filename = f"{ontology_name}.csv"  # Filename based on ontology

# Path to the downloaded OWL file (update this if needed)
local_owl_file = "/content/envo2.owl"  # Change this to your actual file path

# Initialize RDF Graph
g = rdflib.Graph()

# Load the ontology from the local OWL file
g.parse(local_owl_file, format="xml")  # OWL files are typically XML-based

# Extract all properties dynamically by finding all predicates in triples
all_properties = set(g.predicates())

# Extract all triples where these properties are used
triples = []
for prop in all_properties:
    for s, _, o in g.triples((None, prop, None)):
        triples.append((s, prop, o))

# Function to extract local names from URIs
def get_local_name(uri):
    if isinstance(uri, rdflib.term.URIRef):
        return uri.split("#")[-1] if "#" in uri else uri.split("/")[-1]
    elif isinstance(uri, rdflib.term.Literal):
        return str(uri)
    return uri  # Return as-is if not a URI or Literal

# Process triples into a structured format
formatted_triples = []
for s, p, o in triples:
    formatted_triples.append([get_local_name(s), get_local_name(p), get_local_name(o)])

# Save formatted triples to a CSV file
csv_filepath = f"/content/drive/MyDrive/AquaDiva/BioPortalTriples/{csv_filename}"  # Save to a persistent path
with open(csv_filepath, mode="w", newline="", encoding="utf-8") as file:
    writer = csv.writer(file)
    writer.writerow(["Subject", "Predicate", "Object"])  # CSV header
    writer.writerows(formatted_triples)

print(f"\n✅ Data saved to {csv_filename} successfully!")
# Out:
# ✅ Data saved to ENVO.csv successfully!

# %% [markdown]
# ## Labeled Ontology

# %%
import rdflib
import csv

# Define ontology details
ontology_name = "ENVO"  # Update as needed
csv_filename = f"{ontology_name}_labeled.csv"

# Path to the OWL or OBO file (update this!)
ontology_file = "/content/envo2.owl"  # Change for your file

# Initialize RDF Graph
g = rdflib.Graph()

# Load ontology from OWL file (for OBO, use 'pronto' instead)
g.parse(ontology_file, format="xml")

# Function to get labels from URIs
def get_label(uri):
    label = None
    if isinstance(uri, rdflib.term.URIRef):
        # Try fetching the rdfs:label for this entity
        for _, _, label_value in g.triples((uri, rdflib.RDFS.label, None)):
            label = str(label_value)
            break
        return label if label else uri.split("#")[-1] if "#" in uri else uri.split("/")[-1]
    elif isinstance(uri, rdflib.term.Literal):
        return str(uri)
    return uri  # Return as-is if not URI or Literal

# Extract all predicates and their triples
triples = []
for s, p, o in g:
    subject_label = get_label(s)
    predicate_label = get_label(p)
    object_label = get_label(o)

    # Append only if labels exist
    if subject_label and predicate_label and object_label:
        triples.append([subject_label, predicate_label, object_label])

# Save the improved triples to a CSV file
csv_filepath = f"/content/drive/MyDrive/AquaDiva/BioPortalTriples/{csv_filename}"
with open(csv_filepath, mode="w", newline="", encoding="utf-8") as file:
    writer = csv.writer(file)
    writer.writerow(["Subject", "Predicate", "Object"])  # CSV header
    writer.writerows(triples)

print(f"\n✅ Data saved to {csv_filename} successfully!")
# Out:
# ✅ Data saved to ENVO_labeled.csv successfully!

# %% [markdown]
# ## Cleaned Ontology

# %%
import pandas as pd
import rdflib
import requests
import re

# Load labeled triples CSV
csv_filepath = "/content/drive/MyDrive/AquaDiva/BioPortalTriples/ENVO_cleaned_Final.csv"  # Input file
output_csv_filepath = "/content/drive/MyDrive/AquaDiva/BioPortalTriples/ENVO_cleaned_FinalFinal.csv"  # Output file

# Load RDF ontology (if available) to retrieve labels
#ontology_file = "/content/envo2.owl"  # Change this to your ontology file
#g = rdflib.Graph()
#g.parse(ontology_file, format="xml")  # Load ontology

# Convert to lowercase for easier filtering
df = pd.read_csv(csv_filepath)
df = df.astype(str).applymap(lambda x: x.strip().lower())

# List of unwanted exact values
unwanted_exact_values = {"id", "comment", "type", "class", "definition", "label", "true", "envo", "database_cross_reference", "date", "chebi", "has_exact_synonym", "envoempo", "created", "creator", "editor", "	has_alternative_id", "has_related_synonym", "has_narrow_synonym", "envocmecs", "envoplastics", "alternative term", "has_broad_synonym", "term editor","creation_date", "created_by", " has_alternative_id", "has_alternative_id ", "hassynonym", "editor note", "domain", "envoatmo", "ester", "ro-eco", "curator note", "curator"}

# Regex for detecting UUID-like alphanumeric strings
uuid_pattern = re.compile(r"^[a-f0-9]{32}$|^[a-z0-9]{30,}$")

# Regex for ORCID IDs
orcid_pattern = re.compile(r"^(orcid:)?\d{4}-\d{4}-\d{4}-\d{3}[0-9xX]$")

# Function to get human-readable labels from RDF
def get_label(uri):
    if isinstance(uri, rdflib.term.URIRef):
        # Try fetching the rdfs:label for this entity
        for _, _, label_value in g.triples((uri, rdflib.RDFS.label, None)):
            return str(label_value)
        return uri.split("#")[-1] if "#" in uri else uri.split("/")[-1]
    elif isinstance(uri, rdflib.term.Literal):
        return str(uri)
    return uri  # Return as-is if it's not a URI or Literal

# Function to query ORCID API for human-readable names
def get_orcid_name(orcid_id):
    if orcid_id.startswith("orcid:"):
        orcid_id = orcid_id.split(":")[1]  # Remove "orcid:" prefix
    url = f"https://pub.orcid.org/v3.0/{orcid_id}"
    headers = {"Accept": "application/json"}
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        data = response.json()
        try:
            return data["person"]["name"]["given-names"]["value"] + " " + data["person"]["name"]["family-name"]["value"]
        except KeyError:
            return orcid_id  # If name not found, return original ID
    return orcid_id  # Return original if no match

# Function to retrieve labels for ontology terms (e.g., foodon:, chebi:)
def get_ontology_label(term):
    prefix_mapping = {
        "foodon": "https://www.ebi.ac.uk/ols/api/ontologies/foodon/terms?short_form=",
        "chebi": "https://www.ebi.ac.uk/ols/api/ontologies/chebi/terms?short_form="
    }

    for prefix, api_url in prefix_mapping.items():
        if term.startswith(f"{prefix}:"):
            term_id = term.split(":")[1]
            response = requests.get(api_url + term_id, headers={"Accept": "application/json"})
            if response.status_code == 200:
                data = response.json()
                if "_embedded" in data and "terms" in data["_embedded"]:
                    return data["_embedded"]["terms"][0]["label"]  # Extract label from OLS API
            return term  # If API fails, return original term

    return term  # Return original if no match

# Function to clean and replace values with human-readable labels
def clean_and_replace(value):
    if value in unwanted_exact_values:  # Exact match with unwanted words
        return None
    if value.startswith("http://") or value.startswith("https://")or value.startswith("envo:") or value.startswith("iao_") or value.startswith("foodon:") or value.startswith("contributor") or value.startswith("ro_"):  # Is a URL
        return None
    if uuid_pattern.match(value):  # Matches UUID-like strings
        return None
    #if orcid_pattern.match(value):  # Matches ORCID ID
     #   return get_orcid_name(value)
    #if ":" in value:  # Likely an ontology term
     #   return get_ontology_label(value)
    return value  # Return as-is if no match

# Apply filtering and replacement
df_cleaned = df.applymap(clean_and_replace).dropna()

# Save cleaned triples
df_cleaned.to_csv(output_csv_filepath, index=False)

print(f"\n✅ Cleaned triples saved to {output_csv_filepath} successfully!")
# Out:
# <ipython-input-97-f71c8d14cfbb>:17: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.astype(str).applymap(lambda x: x.strip().lower())
# <ipython-input-97-f71c8d14cfbb>:88: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df_cleaned = df.applymap(clean_and_replace).dropna()
# ✅ Cleaned triples saved to /content/drive/MyDrive/AquaDiva/BioPortalTriples/ENVO_cleaned_FinalFinal.csv successfully!

# %%
#import rdflib

# Load the ontology from BioPortal
#ontology_url = "https://data.bioontology.org/ontologies/OBOE-SBC/submissions/1/download?apikey=87918894-263d-4f71-9b22-bfc345c1800d"

# Initialize RDF Graph
#g = rdflib.Graph()
#g.parse(ontology_url, format="application/rdf+xml")

# Extract "is a" relations (subclasses)
#subclass_triples = []
#for s, _, o in g.triples((None, rdflib.RDFS.subClassOf, None)):
 #   subclass_triples.append((s, "is a", o))

# Extract subproperty relations (subproperties)
#subproperty_triples = []
#for s, _, o in g.triples((None, rdflib.RDFS.subPropertyOf, None)):
 #   subproperty_triples.append((s, "is a (subproperty of)", o))

# Function to format triples for readability
#def format_triples(triples):
 #   formatted = []
  #  for s, rel, o in triples:
   #     formatted.append(f"<{s}> --[{rel}]--> <{o}>")
    #return formatted

# Print "is a" subclass relations
#print("\n🔹 'Is A' (Subclass) Relations:")
#for triple in format_triples(subclass_triples):
 #   print(triple)

# Print subproperty relations
#print("\n🔹 'Is A' (Subproperty) Relations:")
#for triple in format_triples(subproperty_triples):
 #   print(triple)

# %%
# !pip install pronto
# Out:
# Collecting pronto
#   Downloading pronto-2.6.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: chardet~=5.0 in /usr/local/lib/python3.11/dist-packages (from pronto) (5.2.0)
# Collecting fastobo~=0.13.0 (from pronto)
#   Downloading fastobo-0.13.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: networkx<4.0,>=2.3 in /usr/local/lib/python3.11/dist-packages (from pronto) (3.4.2)
# Requirement already satisfied: python-dateutil~=2.8 in /usr/local/lib/python3.11/dist-packages (from pronto) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil~=2.8->pronto) (1.17.0)
# Downloading pronto-2.6.0-py3-none-any.whl (83 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.2/83.2 kB 1.9 MB/s eta 0:00:00
# Downloading fastobo-0.13.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 10.1 MB/s eta 0:00:00
# Installing collected packages: fastobo, pronto
# Successfully installed fastobo-0.13.0 pronto-2.6.0

# %%
import pronto
import csv

# Define ontology file path
obo_file_path = "/content/drive/MyDrive/AquaDiva/LLMTriples/chebi.obo"  # Update this with your actual file path

# Load the ChEBI ontology
ontology = pronto.Ontology(obo_file_path)

# List to store extracted triples
triples = []

# Iterate through all terms in the ontology
for term in ontology.terms():
    subject = term.name  # Get the human-readable name of the term
    subject_id = term.id  # ChEBI ID of the term
    if not subject:
        continue  # Skip terms without names

    # Extract "is_a" (subclass) relationships
    for parent in term.superclasses(distance=1):  # Direct parents only
        triples.append((subject, "is a", parent.id))  # Using ChEBI ID as object

    # Extract "relationship" (custom properties)
    for relation, targets in term.relationships.items():  # Fix: Use `.relationships`
        for target in targets:
            triples.append((subject, relation.name, target.id))  # Relation ID for clarity

# Save extracted triples to a CSV file
csv_filepath = "/content/drive/MyDrive/AquaDiva/BioPortalTriples/chebi_triples.csv"
with open(csv_filepath, mode="w", newline="", encoding="utf-8") as file:
    writer = csv.writer(file)
    writer.writerow(["Subject", "Predicate", "Object"])  # CSV header
    writer.writerows(triples)

# Print extracted triples
print("\n🔹 Extracted ChEBI Triples:")
for triple in triples[:10]:  # Print only first 10 triples for preview
    print(f"({triple[0]}) -[{triple[1]}]-> ({triple[2]})")

print(f"\n✅ ChEBI triples saved to {csv_filepath} successfully!")
# Out:
# 🔹 Extracted ChEBI Triples:
# (chemical entity) -[is a]-> (CHEBI:24431)
# (molecular entity) -[is a]-> (CHEBI:23367)
# (molecular entity) -[is a]-> (CHEBI:24431)
# (ion) -[is a]-> (CHEBI:24870)
# (ion) -[is a]-> (CHEBI:23367)
# (monoatomic ion) -[is a]-> (CHEBI:24867)
# (monoatomic ion) -[is a]-> (CHEBI:24870)
# (monoatomic ion) -[is a]-> (CHEBI:33238)
# (monoatomic anion) -[is a]-> (CHEBI:23905)
# (monoatomic anion) -[is a]-> (CHEBI:22563)
#
# ✅ ChEBI triples saved to /content/drive/MyDrive/AquaDiva/BioPortalTriples/chebi_triples.csv successfully!

# %%
import pronto
import pandas as pd

# Load the ChEBI ontology
obo_file_path = "/content/drive/MyDrive/AquaDiva/LLMTriples/chebi.obo"  # Update this with your actual file path
ontology = pronto.Ontology(obo_file_path)

# Load the extracted triples CSV
csv_filepath = "/content/drive/MyDrive/AquaDiva/BioPortalTriples/chebi_triples.csv"  # Input CSV with IDs
output_csv_filepath = "/content/drive/MyDrive/AquaDiva/BioPortalTriples/chebi_triples_named.csv"  # Output CSV with names

# Load the CSV into a pandas DataFrame
df = pd.read_csv(csv_filepath)

# Function to get the name of a ChEBI ID
def get_chebi_name(chebi_id):
    if isinstance(chebi_id, str) and chebi_id.startswith("CHEBI:"):
        term = ontology.get(chebi_id)  # Look up the term in the ontology
        return term.name if term else chebi_id  # Return the name if found, otherwise keep the ID
    return chebi_id  # If not a ChEBI ID, return as is

# Apply the function to replace ChEBI IDs in the "Object" column
df["Object"] = df["Object"].apply(get_chebi_name)

# Save the updated triples to a new CSV file
df.to_csv(output_csv_filepath, index=False)

# Print a preview of the updated triples
print("\n🔹 Updated ChEBI Triples (with Names):")
print(df.head(10))  # Show the first 10 rows

print(f"\n✅ Named ChEBI triples saved to {output_csv_filepath} successfully!")
# Out:
# 🔹 Updated ChEBI Triples (with Names):
#             Subject Predicate             Object
# 0   chemical entity      is a    chemical entity
# 1  molecular entity      is a   molecular entity
# 2  molecular entity      is a    chemical entity
# 3               ion      is a                ion
# 4               ion      is a   molecular entity
# 5    monoatomic ion      is a     monoatomic ion
# 6    monoatomic ion      is a                ion
# 7    monoatomic ion      is a  monoatomic entity
# 8  monoatomic anion      is a   monoatomic anion
# 9  monoatomic anion      is a              anion
#
# ✅ Named ChEBI triples saved to /content/drive/MyDrive/AquaDiva/BioPortalTriples/chebi_triples_named.csv successfully!

# %%
from rdflib import Graph

def convert_ontology_to_rdf(ontology_file, output_file):
    # Create a Graph
    g = Graph()

    # Parse the ontology file
    g.parse(ontology_file, format='xml')  # Assuming OWL/XML format

    # Serialize the graph into RDF triples (Turtle format)
    rdf_triples = g.serialize(format='turtle')

    # Save to file
    with open(output_file, "w", encoding="utf-8") as f:
        f.write(rdf_triples)

    print(f"RDF triples have been saved to {output_file}")

# Example usage
ontology_file = "/content/envo2.owl"  # Path to the ontology file
output_file = "/content/test_envo2.owl"  # Output RDF file in Turtle format
convert_ontology_to_rdf(ontology_file, output_file)
# Out:
# RDF triples have been saved to /content/test_envo2.owl

# %%
import pandas as pd

# Load the named triples CSV
input_csv_filepath = "/content/drive/MyDrive/AquaDiva/BioPortalTriples/chebi_triples_named.csv"  # Input file
output_csv_filepath = "/content/drive/MyDrive/AquaDiva/BioPortalTriples/chebi_triples_cleaned.csv"  # Output file

# Load CSV into pandas DataFrame
df = pd.read_csv(input_csv_filepath)

# Function to check if any cell in the row has more than 25 characters
def filter_short_entries(row):
    return all(len(str(cell)) <= 25 for cell in row)

# Apply the filter
df_cleaned = df[df.apply(filter_short_entries, axis=1)]

# Save the cleaned triples to a new CSV file
df_cleaned.to_csv(output_csv_filepath, index=False)

# Print a preview of the cleaned triples
print("\n🔹 Cleaned ChEBI Triples (≤ 25 chars per cell):")
print(df_cleaned.head(10))  # Show the first 10 rows

print(f"\n✅ Cleaned triples saved to {output_csv_filepath} successfully!")
# Out:
# 🔹 Cleaned ChEBI Triples (≤ 25 chars per cell):
#             Subject Predicate             Object
# 0   chemical entity      is a    chemical entity
# 1  molecular entity      is a   molecular entity
# 2  molecular entity      is a    chemical entity
# 3               ion      is a                ion
# 4               ion      is a   molecular entity
# 5    monoatomic ion      is a     monoatomic ion
# 6    monoatomic ion      is a                ion
# 7    monoatomic ion      is a  monoatomic entity
# 8  monoatomic anion      is a   monoatomic anion
# 9  monoatomic anion      is a              anion
#
# ✅ Cleaned triples saved to /content/drive/MyDrive/AquaDiva/BioPortalTriples/chebi_triples_cleaned.csv successfully!

# %%
import rdflib
import re
import csv
from rdflib.namespace import OWL, RDF, RDFS

# Path to the downloaded OWL file (update this if needed)
local_owl_file = "/content/oboe-sbc.owl"  # Change this to your actual file path
csv_output_file = "/content/oboe-sbc.csv"  # Output file path

# Initialize RDF Graph
g = rdflib.Graph()

# Load the ontology from the local OWL file
g.parse(local_owl_file, format="xml")  # OWL files are typically XML-based

# Function to retrieve the human-readable label for an ontology term
def get_label(uri):
    """ Returns the rdfs:label (name) of a term if available, otherwise its local name. """
    if isinstance(uri, rdflib.BNode):  # Ignore blank nodes
        return None
    if isinstance(uri, rdflib.URIRef):
        for _, _, label in g.triples((uri, RDFS.label, None)):  # Check for rdfs:label
            return str(label)
        return uri.split("#")[-1] if "#" in uri else uri.split("/")[-1]  # Fallback: Use last part of URI
    elif isinstance(uri, rdflib.Literal):
        return str(uri)  # If it's already readable, return as is
    return uri  # Return as-is if not a URI or Literal

# Regex to detect random alphanumeric strings (UUID-like)
uuid_pattern = re.compile(r"^[a-f0-9]{30,}$")

# Function to check if a value is invalid (UUID-like or blank node)
def is_invalid(value):
    return value is None or uuid_pattern.match(value)  # Returns True if value is None or a UUID

# List to store extracted triples
triples = []

### 🔹 Step 1: Extract Standard RDF Triples (Filtering Out "subClassOf" and Random Strings) ###
all_properties = set(g.predicates())

for prop in all_properties:
    if prop in {RDFS.subClassOf, OWL.equivalentClass}:  # Skip generic relations
        continue
    for s, _, o in g.triples((None, prop, None)):
        subject, predicate, object_ = get_label(s), get_label(prop), get_label(o)

        # Ignore triples with UUID-like strings or blank nodes
        if is_invalid(subject) or is_invalid(predicate) or is_invalid(object_):
            continue

        triples.append([subject, predicate, object_])

### 🔹 Step 2: Extract OWL Property Restrictions (Complex Relations) ###
for restriction in g.subjects(RDF.type, OWL.Restriction):
    for _, _, prop in g.triples((restriction, OWL.onProperty, None)):
        predicate = get_label(prop)

        for s, _, _ in g.triples((None, None, restriction)):
            subject = get_label(s)

            for _, _, obj in g.triples((restriction, OWL.someValuesFrom, None)):
                object_ = get_label(obj)

                # Ignore triples with UUID-like strings or blank nodes
                if is_invalid(subject) or is_invalid(predicate) or is_invalid(object_):
                    continue

                triples.append([subject, predicate, object_])

# Save extracted triples to a CSV file
with open(csv_output_file, mode="w", newline="", encoding="utf-8") as file:
    writer = csv.writer(file)
    writer.writerow(["Subject", "Predicate", "Object"])  # CSV header
    writer.writerows(triples)

# Print confirmation
print(f"\n✅ {len(triples)} meaningful triples extracted and saved to {csv_output_file} successfully!")
# Out:
# ✅ 218 meaningful triples extracted and saved to /content/oboe-sbc.csv successfully!

# %%
import pandas as pd

# Define file paths
file1 = "/content/envo_triples.csv"  # First CSV file
file2 = "/content/drive/MyDrive/AquaDiva/BioPortalTriples/ENVO_cleaned.csv"  # Second CSV file
output_file = "/content/drive/MyDrive/AquaDiva/BioPortalTriples/ENVO_cleaned_Final.csv"  # Output CSV file

# Load the two CSV files
df1 = pd.read_csv(file1)
df2 = pd.read_csv(file2)

# Combine the files (stack them together)
df_combined = pd.concat([df1, df2], ignore_index=True)

# Remove duplicate rows (Optional: Remove this line if you want all rows)
df_combined.drop_duplicates(inplace=True)

# Save the combined file
df_combined.to_csv(output_file, index=False)

print(f"\n✅ Combined CSV saved to: {output_file}")
# Out:
# ✅ Combined CSV saved to: /content/drive/MyDrive/AquaDiva/BioPortalTriples/ENVO_cleaned_Final.csv
